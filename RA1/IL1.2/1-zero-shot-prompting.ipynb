# %% [markdown]
# [![Abrir en Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/fvalenzuelag/Ingenier-a-de-Soluciones-con-Inteligencia-Artificial/blob/Mistral/RA1/IL1.2/1-zero-shot-prompting.ipynb)

# %% [markdown]
# # 1. Zero-Shot Prompting - Prompts Sin Ejemplos Previos
#
# ## Objetivos de Aprendizaje
# - Comprender los principios del zero-shot prompting
# - Diseñar prompts efectivos sin ejemplos previos
# - Aplicar técnicas de instrucción clara y contexto
# - Evaluar la efectividad de diferentes enfoques zero-shot
#
# ## ¿Qué es Zero-Shot Prompting?
#
# Zero-shot prompting es la técnica donde pedimos al modelo realizar una tarea **sin proporcionar ejemplos específicos** de cómo debe hacerla. El modelo debe basarse únicamente en:
# - Su entrenamiento previo
# - Las instrucciones que le damos
# - El contexto que proporcionamos
#
# ### Ventajas:
# - **Simplicidad**: No requiere crear ejemplos
# - **Flexibilidad**: Fácil de adaptar a nuevas tareas
# - **Eficiencia**: Menos tokens utilizados
# - **Generalización**: Funciona para tareas diversas
#
# ### Limitaciones:
# - **Inconsistencia**: Resultados pueden variar más
# - **Formato**: Menos control sobre la estructura de salida
# - **Tareas complejas**: Puede requerir instrucciones muy detalladas
# - **Dominio específico**: Menos efectivo en nichos especializados

# %%
# --- Instalación de dependencias (se ejecuta solo en Google Colab) ---
# En local no hace nada: usa `pip install -r requirements.txt` desde la raíz del repo.
import sys
if "google.colab" in sys.modules:
    # !pip install -q langchain langchain-classic langchain-openai python-dotenv
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 18.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.1/125.1 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.0/570.0 kB 27.5 MB/s eta 0:00:00

# %%
# --- Credenciales: funciona en local (.env) y en Google Colab (Secrets) ---
import os
try:
    from google.colab import userdata          # Colab: panel 🔑 Secrets
    # Solo LLM_API_KEY es obligatorio. Los demás son opcionales: defínelos como
    # Secrets únicamente si quieres usar otro proveedor o modelo.
    for _k in ("LLM_API_KEY", "GOOGLE_API_KEY", "LANGSMITH_API_KEY",
               "LLM_BASE_URL", "LLM_MODEL", "LLM_MODEL_SMALL"):
        try:
            os.environ[_k] = userdata.get(_k)
        except Exception:
            pass                                # el Secret no existe: se usa el default
    os.environ.setdefault("LLM_BASE_URL", "https://api.mistral.ai/v1")
    os.environ.setdefault("LLM_MODEL", "mistral-small-latest")
    os.environ.setdefault("LLM_MODEL_SMALL", "ministral-8b-latest")
except ImportError:
    from dotenv import load_dotenv             # Local: archivo .env en la raíz
    load_dotenv()

# Configuración inicial
from langchain_openai import ChatOpenAI
# LangChain v1: langchain_core.messages / langchain_core.documents
from langchain_classic.schema import HumanMessage, SystemMessage
import os
import time

# Configurar el modelo
llm = ChatOpenAI(
    base_url=os.getenv("LLM_BASE_URL"),
    api_key=os.getenv("LLM_API_KEY"),
    model=os.getenv("LLM_MODEL", "mistral-small-latest"),
    temperature=0.7  # Balance entre creatividad y consistencia
)

print("✓ Modelo configurado para zero-shot prompting")
# Out:
# ✓ Modelo configurado para zero-shot prompting

# %% [markdown]
# ## Anatomía de un Prompt Zero-Shot Efectivo
#
# Un prompt zero-shot efectivo tiene estos componentes:
#
# 1. **Contexto/Rol**: Quién debe "ser" el modelo
# 2. **Tarea**: Qué debe hacer específicamente
# 3. **Formato**: Cómo debe estructurar la respuesta
# 4. **Restricciones**: Qué debe evitar o considerar
# 5. **Input**: Los datos específicos a procesar

# %%
# Ejemplo básico vs mejorado
def comparar_prompts_basico():
    texto = "El nuevo iPhone tiene una batería increíble y la cámara es fantástica, pero el precio es muy Alto."

    # Prompt básico (menos efectivo)
    prompt_basico = f"Analiza este texto: {texto}"

    # Prompt mejorado (más efectivo)
    prompt_mejorado = f"""Eres un analista de sentimientos experto.

Tarea: Analiza el sentimiento del siguiente texto sobre un producto.

Formato de respuesta:
- Sentimiento general: [Positivo/Negativo/Neutral]
- Aspectos positivos: [lista]
- Aspectos negativos: [lista]
- Puntuación de confianza: [0-10]

Texto a analizar: "{texto}"""

    print("=== COMPARACIÓN DE PROMPTS ===")

    # Probar prompt básico
    print("\n1. PROMPT BÁSICO:")
    print(f"Prompt: {prompt_basico}")
    try:
        response1 = llm.invoke([HumanMessage(content=prompt_basico)])
        print(f"Respuesta: {response1.content}")
    except Exception as e:
        print(f"Error: {e}")

    print("\n" + "-"*60)

    # Probar prompt mejorado
    print("\n2. PROMPT MEJORADO:")
    print(f"Prompt: {prompt_mejorado[:100]}...")
    try:
        response2 = llm.invoke([HumanMessage(content=prompt_mejorado)])
        print(f"Respuesta: {response2.content}")
    except Exception as e:
        print(f"Error: {e}")

    print("\n=== ANÁLISIS ===")
    print("• Prompt básico: Ambiguo, respuesta poco estructurada")
    print("• Prompt mejorado: Específico, respuesta estructurada y útil")

# Ejecutar comparación
comparar_prompts_basico()
# Out:
# === COMPARACIÓN DE PROMPTS ===
#
# 1. PROMPT BÁSICO:
# Prompt: Analiza este texto: El nuevo iPhone tiene una batería increíble y la cámara es fantástica, pero el precio es muy Alto.
# Respuesta: El texto que has compartido es una **reseña breve y subjetiva** sobre el nuevo iPhone, destacando tanto aspectos positivos como negativos. Aquí tienes un análisis detallado:
#
# ### **1. Estructura y contenido**
# - **Estructura simple**: Frases cortas y directas, típicas de reseñas o comentarios informales en redes sociales o plataformas como Amazon o foros de tecnología.
# - **Enfoque en características clave**:
#   - **Aspectos positivos**:
#     - **Batería**: Se describe como "increíble" (superlativo que sugiere una gran capacidad o duración).
#     - **Cámara**: Adjetivada como "fantástica" (indica alta calidad en fotografía/videografía).
#   - **Aspecto negativo**:
#     - **Precio**: Se critica con el adjetivo "muy alto", lo que implica que el dispositivo es caro en comparación con su valor percibido o con alternativas del mercado.
#
# ### **2. Lenguaje y estilo**
# - **Coloquial y emotivo**:
#   - Uso de adjetivos exagerados ("increíble", "fantástica", "muy alto") para transmitir una opinión personal.
#   - **Falta de datos concretos**: No se mencionan cifras (ej.: "la batería dura 24 horas") ni comparaciones (ej.: "mejor que el modelo anterior"), lo que lo hace más subjetivo.
# - **Tono equilibrado**:
#   - Aunque reconoce puntos fuertes, el comentario negativo (precio) podría influir en la percepción general del producto.
#
# ### **3. Contexto de uso**
# Este tipo de texto es común en:
# - **Reseñas de productos** (ej.: Amazon, Google Play Store).
# - **Comentarios en redes sociales** (Twitter, Instagram, TikTok).
# - **Foros de tecnología** (Reddit, Xataka, etc.).
# - **Conversaciones informales** entre usuarios.
#
# ### **4. Posibles intenciones del autor**
# - **Informar**: Dar una opinión inicial sobre el dispositivo.
# - **Influir**: Alertar a otros usuarios sobre el alto costo o destacar fortalezas.
# - **Generar engagement**: En redes, este tipo de frases polémicas o equilibradas suelen generar respuestas o debates.
#
# ### **5. Comparación con otros estilos**
# - **Reseña profesional**: Incluiría datos técnicos (ej.: "la batería de 4000 mAh dura 18 horas en uso intensivo"), benchmarks, y un análisis más detallado de pros/contras.
# - **Crítica negativa**: Podría enfatizar solo los aspectos negativos (ej.: "la cámara es buena, pero el precio es absurdo").
# - **Publicidad corporativa**: Destacaría solo las ventajas sin mencionar el precio.
#
# ### **6. Variantes posibles**
# El mensaje podría modificarse para:
# - **Ser más técnico**:
#   *"El iPhone X tiene una batería de 4000 mAh que dura hasta 20 horas en uso mixto, pero su cámara de 48 MP no supera a la competencia en condiciones de poca luz. Además, el precio de $1200 lo hace poco accesible."*
# - **Ser más positivo**:
#   *"El nuevo iPhone tiene una batería de larga duración y una cámara profesional, ¡es el mejor smartphone del mercado!"*
# - **Ser más negativo**:
#   *"El iPhone es caro y su batería no es tan buena como dicen. La cámara es lo único destacable."*
#
# ### **7. Impacto en el receptor**
# - **Para un consumidor potencial**:
#   - Podría generar interés por las características técnicas, pero disuadir por el precio.
#   - Dependería de si prioriza cámara/batería o presupuesto.
# - **Para la marca (Apple)**:
#   - Señal de que los usuarios valoran el hardware pero cuestionan el valor monetario.
#   - Posible estrategia de marketing para justificar el precio (ej.: "invertir en calidad").
#
# ### **Conclusión**
# Es un **comentario equilibrado pero opinativo**, típico de usuarios que evalúan productos de forma rápida. Su fuerza radica en la simplicidad y la capacidad de resumir ventajas y desventajas clave en pocas palabras. Para un análisis más profundo, sería necesario contrastarlo con datos técnicos o comparativas de mercado.
#
# ¿Te gustaría profundizar en algún aspecto en particular?
#
# ------------------------------------------------------------
#
# 2. PROMPT MEJORADO:
# Prompt: Eres un analista de sentimientos experto.
#
# Tarea: Analiza el sentimiento del siguiente texto so...
# Respuesta: - **Sentimiento general:** Neutral (mezcla de aspectos positivos y negativos)
# - **Aspectos positivos:**
#   - Batería "increíble" (elogio explícito).
#   - Cámara "fantástica" (valoración muy positiva).
# - **Aspectos negativos:**
#   - Precio "muy alto" (crítica explícita).
# - **Puntuación de confianza:** 9 (el sentimiento está claramente equilibrado entre positivo y negativo, con términos muy definidos).
#
# === ANÁLISIS ===
# • Prompt básico: Ambiguo, respuesta poco estructurada
# • Prompt mejorado: Específico, respuesta estructurada y útil

# %% [markdown]
# ## Técnicas de Zero-Shot por Tipo de Tarea
#
# Diferentes tipos de tareas requieren enfoques específicos en zero-shot prompting.

# %%
# 1. CLASIFICACIÓN
def zero_shot_clasificacion():
    print("=== ZERO-SHOT PARA CLASIFICACIÓN ===")

    emails = [
        "Reunión del club de perritos rescatados",
        "¡Felicidades! Has ganado $1,000,000! Haz clic aquí ahora",
        "Recordatorio: Tu factura de internet vence en 3 días"
    ]

    # Prompt optimizado para clasificación
    clasificacion_prompt = """Eres un clasificador de emails empresariales.

Clasifica cada email en una de estas categorías:
- TRABAJO: Relacionado con tareas laborales
- SPAM: Contenido no solicitado o sospechoso
- PERSONAL: Asuntos personales o administrativos

Responde solo con el nombre de la categoría.

Email: "{}"
Categoría:"""

    for i, email in enumerate(emails, 1):
        prompt = clasificacion_prompt.format(email)
        try:
            response = llm.invoke([HumanMessage(content=prompt)])
            print(f"{i}. Email: {email[:50]}...")
            print(f"   Clasificación: {response.content.strip()}\n")
        except Exception as e:
            print(f"Error en email {i}: {e}")

# Ejecutar clasificación
zero_shot_clasificacion()
# Out:
# === ZERO-SHOT PARA CLASIFICACIÓN ===
# 1. Email: Reunión del club de perritos rescatados...
#    Clasificación: PERSONAL
#
# 2. Email: ¡Felicidades! Has ganado $1,000,000! Haz clic aquí...
#    Clasificación: SPAM
#
# 3. Email: Recordatorio: Tu factura de internet vence en 3 dí...
#    Clasificación: PERSONAL

# %%
# 2. GENERACIÓN DE CONTENIDO
def zero_shot_generacion():
    print("=== ZERO-SHOT PARA GENERACIÓN ===")

    # Prompt estructurado para generación
    generacion_prompt = """Eres un copywriter creativo especializado en redes sociales.

Tarea: Crear un post para LinkedIn sobre el tema dado.

Requisitos:
- Tono profesional pero accesible
- Máximo 150 palabras
- Incluir 1-2 hashtags relevantes
- Hacer una pregunta para fomentar engagement

Tema: "Importancia del aprendizaje continuo en tecnología"

Post para LinkedIn:"""

    try:
        response = llm.invoke([HumanMessage(content=generacion_prompt)])
        print("Post generado:")
        print("-" * 40)
        print(response.content)
        print("-" * 40)

        # Análisis del resultado
        words = len(response.content.split())
        hashtags = response.content.count('#')
        questions = response.content.count('?')

        print(f"\nAnálisis:")
        print(f"• Palabras: {words} (límite: 150)")
        print(f"• Hashtags: {hashtags}")
        print(f"• Preguntas: {questions}")
        print(f"• Cumple requisitos: {'✓' if words <= 150 and hashtags >= 1 and questions >= 1 else '✗'}")

    except Exception as e:
        print(f"Error: {e}")

# Ejecutar generación
zero_shot_generacion()
# Out:
# === ZERO-SHOT PARA GENERACIÓN ===
# Post generado:
# ----------------------------------------
# **🚀 ¿Estás listo para el futuro de la tecnología?**
#
# En un mundo donde la innovación avanza a velocidad de luz, **el aprendizaje continuo no es una opción, es una necesidad**. La tecnología evoluciona constantemente, y quienes se quedan atrás… quedan fuera.
#
# Ya sea dominando IA, ciberseguridad o cloud computing, **la clave del éxito está en mantenerse actualizado**. Plataformas como Coursera, Udemy o incluso los recursos gratuitos de Google y Microsoft son aliados poderosos.
#
# Pero, ¿cómo incorporas el aprendizaje en tu rutina profesional? ¿Qué habilidades tecnológicas consideras imprescindibles para este año?
#
# 💡 **Comenta abajo y compartamos ideas** para crecer juntos en este emocionante viaje.
#
# #AprenderParaCrecer #TecnologíaEnEvolución
# ----------------------------------------
#
# Análisis:
# • Palabras: 105 (límite: 150)
# • Hashtags: 2
# • Preguntas: 3
# • Cumple requisitos: ✓

# %%
# 3. EXTRACCIÓN DE INFORMACIÓN
def zero_shot_extraccion():
    print("=== ZERO-SHOT PARA EXTRACCIÓN ===")

    # Texto de ejemplo
    texto_noticia = """Apple Inc. anunció hoy que su CEO Tim Cook se reunirá con inversores
    el próximo 15 de marzo de 2024 en Cupertino, California. La reunión abordará los
    resultados financieros del Q1 2024, donde la compañía reportó ingresos de $89.5
    billones. Cook también discutirá la nueva estrategia de IA de Apple y el lanzamiento
    del iPhone 16 programado para septiembre. Las acciones de Apple (AAPL) subieron
    3.2% tras el anuncio."""

    # Prompt para extracción estructurada
    extraccion_prompt = f"""Eres un analista financiero experto en extraer datos clave.

Extrae la siguiente información del texto dado:

Formato de respuesta (JSON):
{{
  "empresa": "nombre de la empresa",
  "ceo": "nombre del CEO",
  "fecha_evento": "fecha del evento",
  "ubicacion": "ubicación del evento",
  "ingresos": "cifra de ingresos mencionada",
  "productos": ["lista de productos mencionados"],
  "cambio_acciones": "porcentaje de cambio en acciones"
}}

Texto: "{texto_noticia}"

JSON:"""

    try:
        response = llm.invoke([HumanMessage(content=extraccion_prompt)])
        print("Información extraída:")
        print(response.content)

        # Intentar parsear como JSON para validar formato
        import json
        try:
            data = json.loads(response.content)
            print("\n✓ Formato JSON válido")
            print(f"✓ Campos extraídos: {len(data)} elementos")
        except:
            print("\n✗ Formato JSON inválido - necesita refinamiento del prompt")

    except Exception as e:
        print(f"Error: {e}")

# Ejecutar extracción
zero_shot_extraccion()
# Out:
# === ZERO-SHOT PARA EXTRACCIÓN ===
# Información extraída:
# ```json
# {
#   "empresa": "Apple Inc.",
#   "ceo": "Tim Cook",
#   "fecha_evento": "15 de marzo de 2024",
#   "ubicacion": "Cupertino, California",
#   "ingresos": "$89.5 billones",
#   "productos": ["iPhone 16"],
#   "cambio_acciones": "3.2%"
# }
# ```
#
# ✗ Formato JSON inválido - necesita refinamiento del prompt

# %% [markdown]
# ## Optimización de Prompts Zero-Shot
#
# Técnicas para mejorar la efectividad de prompts zero-shot.

# %%
# Técnica 1: Prompts con Roles Específicos
def roles_especificos():
    print("=== OPTIMIZACIÓN: ROLES ESPECÍFICOS ===")

    pregunta = "¿Cómo puedo mejorar el rendimiento de mi aplicación web?"

    roles = {
        "Genérico": "Responde la siguiente pregunta:",
        "Desarrollador Senior": "Eres un desarrollador senior con 10 años de experiencia en optimización web. Responde como un experto:",
        "Consultor de Performance": "Eres un consultor especializado en performance web que ha optimizado cientos de aplicaciones. Proporciona una respuesta detallada y técnica:",
        "CTO": "Eres un CTO de una startup tecnológica. Responde con una perspectiva estratégica y técnica balanceada:"
    }

    for rol, contexto in roles.items():
        prompt = f"{contexto}\n\n{pregunta}"

        print(f"\n{rol.upper()}:")
        print("-" * 30)

        try:
            response = llm.invoke([HumanMessage(content=prompt)])
            # Mostrar solo las primeras líneas para comparación
            preview = response.content[:200] + "..." if len(response.content) > 200 else response.content
            print(preview)
        except Exception as e:
            print(f"Error: {e}")

    print("\n=== OBSERVACIONES ===")
    print("• Roles específicos generan respuestas más enfocadas")
    print("• La experticia del rol influye en la profundidad técnica")
    print("• El contexto profesional afecta el tipo de soluciones propuestas")

# Ejecutar ejemplo de roles
roles_especificos()
# Out:
# === OPTIMIZACIÓN: ROLES ESPECÍFICOS ===
#
# GENÉRICO:
# ------------------------------
# Mejorar el rendimiento de una aplicación web es clave para ofrecer una experiencia de usuario fluida y optimizar recursos tanto en el servidor como en el cliente. Aquí tienes un plan estructurado con ...
#
# DESARROLLADOR SENIOR:
# ------------------------------
# ¡Excelente pregunta! Como desarrollador senior con **10 años de experiencia en optimización web**, te daré un enfoque **estructurado y profesional** para mejorar el rendimiento de tu aplicación web, c...
#
# CONSULTOR DE PERFORMANCE:
# ------------------------------
# Mejorar el rendimiento de una aplicación web requiere un enfoque **multidimensional** que abarque desde el **frontend** hasta el **backend**, la **infraestructura** y la **experiencia de usuario**. A ...
#
# CTO:
# ------------------------------
# Mejorar el rendimiento de una aplicación web requiere un enfoque **multi-dimensional**, combinando optimizaciones técnicas, arquitectura escalable y métricas clave. Como CTO, priorizaría un análisis b...
#
# === OBSERVACIONES ===
# • Roles específicos generan respuestas más enfocadas
# • La experticia del rol influye en la profundidad técnica
# • El contexto profesional afecta el tipo de soluciones propuestas

# %%
# Técnica 2: Instrucciones Graduales
def instrucciones_graduales():
    print("=== OPTIMIZACIÓN: INSTRUCCIONES GRADUALES ===")

    # Problema complejo para demostrar
    problema = "Necesito crear una estrategia de marketing digital para lanzar una nueva app de fitness"

    # Prompt con instrucciones graduales
    prompt_gradual = f"""Eres un estratega de marketing digital senior.

Problema: {problema}

Desarrolla una estrategia siguiendo este proceso paso a paso:

PASO 1: Análisis inicial
- Identifica el público objetivo
- Define 3 puntos de valor únicos de la app

PASO 2: Canales de marketing
- Selecciona 4-5 canales digitales más efectivos
- Justifica cada selección

PASO 3: Estrategia de contenido
- Define tipos de contenido para cada canal
- Sugiere frecuencia de publicación

PASO 4: Métricas y KPIs
- Define 5 métricas clave para medir éxito
- Sugiere herramientas de medición

Desarrolla cada paso con detalle:"""

    try:
        response = llm.invoke([HumanMessage(content=prompt_gradual)])
        print("ESTRATEGIA DESARROLLADA:")
        print("=" * 50)
        print(response.content)

        # Análisis de estructura
        pasos_detectados = response.content.count("PASO")
        secciones = ["análisis", "canales", "contenido", "métricas"]
        secciones_encontradas = sum(1 for seccion in secciones if seccion.lower() in response.content.lower())

        print("\n=== ANÁLISIS DE ESTRUCTURA ===")
        print(f"• Pasos identificados: {pasos_detectados}/4")
        print(f"• Secciones cubiertas: {secciones_encontradas}/4")
        print(f"• Estructura seguida: {'✓' if pasos_detectados >= 3 else '✗'}")

    except Exception as e:
        print(f"Error: {e}")

# Ejecutar instrucciones graduales
instrucciones_graduales()
# Out:
# === OPTIMIZACIÓN: INSTRUCCIONES GRADUALES ===
# ESTRATEGIA DESARROLLADA:
# ==================================================
# # **Estrategia de Marketing Digital para Lanzamiento de App de Fitness**
#
# ---
#
# ## **📌 PASO 1: Análisis Inicial**
#
# ### **🎯 Identificación del Público Objetivo**
# La app de fitness debe segmentarse cuidadosamente para maximizar la adquisición y retención de usuarios. Basado en tendencias del mercado y análisis de competencia (ej: Nike Training Club, MyFitnessPal, Freeletics), proponemos los siguientes *personas*:
#
# | **Segmento** | **Características** | **Motivaciones** | **Dolores** |
# |-------------|---------------------|------------------|-------------|
# | **Principiantes en Fitness** (20-35 años) | Sedentarios, poco conocimiento en entrenamiento, buscan guías estructuradas. | Mejorar salud, perder peso, ganar confianza. | Falta de tiempo, frustración por no ver resultados rápidos. |
# | **Deportistas intermedios** (25-40 años) | Hacen ejercicio 3-5 veces/semana, buscan desafíos. | Optimizar rendimiento, evitar lesiones, variar rutinas. | Aburrimiento con rutinas repetitivas, falta de seguimiento profesional. |
# | **Gimnasio + App complementaria** (18-45 años) | Usan apps para tracking (ej: Strava, MyFitnessPal). | Maximizar resultados con tecnología. | Apps genéricas no se integran con sus dispositivos wearables. |
# | **Mamás/papás ocupados** (30-45 años) | Padres con poco tiempo, buscan rutinas en casa. | Equilibrar familia y salud. | Apps complejas o que requieren equipo. |
# | **Fitness enthusiasts** (18-30 años) | Usuarios avanzados, siguen tendencias virales (TikTok, Instagram). | Desafíos virales, comunidad, exclusividad. | Apps "básicas" no satisfacen su nivel de exigencia. |
#
# **🔹 Priorización:**
# - **Enfoque inicial:** Principiantes + Deportistas intermedios (mayor volumen y necesidad de estructura).
# - **Fase 2:** Gimnasio + Fitness enthusiasts (para escalar y fidelizar).
#
# ---
#
# ### **✨ 3 Puntos de Valor Únicos (USP)**
# Para destacar en un mercado saturado (más de **300K apps de fitness** en Google Play y App Store), la app debe ofrecer algo diferenciador. Propuesta:
#
# 1. **🧠 IA Personalizada + Planes Adaptativos**
#    - **Qué:** La app usa *machine learning* para ajustar planes de entrenamiento y nutrición en tiempo real según progreso, lesiones, horarios y preferencias (ej: "Si subes de peso, te sugiero rutinas de HIIT + recetas altas en proteína").
#    - **Ejemplo:** "Tu próximo entrenamiento será de 20 min en casa con bandas porque hoy tienes poco tiempo, pero ayer corriste 5K".
#    - **Diferencial:** La mayoría de apps ofrecen planes estáticos (ej: "Día 1: Sentadillas 4x12"). La IA hace que cada usuario sienta que la app "lo conoce".
#
# 2. **🤝 Comunidad + Gamificación Social**
#    - **Qué:** Integración con *streaks* (ej: "Llevas 10 días consecutivos entrenando"), desafíos grupales (ej: "El equipo que complete más minutos de cardio esta semana gana un mes gratis"), y *live workouts* con entrenadores.
#    - **Ejemplo:** "Retos semanales en TikTok (ej: #7DíasDeCardio) con premios reales (descuentos en suplementos, sesiones 1:1 con influencers fitness)".
#    - **Diferencial:** El 68% de los usuarios abandonan apps de fitness por falta de motivación (estudio de *Journal of Medical Internet Research*). La gamificación aumenta la retención en un **200%** (fuente: *App Annie*).
#
# 3. **📊 Integración con Wearables y Salud**
#    - **Qué:** Sincronización automática con **Apple Health, Google Fit, Apple Watch, Fitbit, Whoop** y medición de:
#      - Frecuencia cardíaca en tiempo real durante el entrenamiento.
#      - Niveles de cortisol (estrés) para ajustar la intensidad.
#      - Sleep score (calidad del sueño) para recomendar días de recuperación.
#    - **Ejemplo:** "Hoy tu frecuencia cardíaca en reposo está alta (posible estrés). Te recomiendo un entrenamiento de yoga en lugar de HIIT".
#    - **Diferencial:** La mayoría de apps solo integran pasos o calorías quemadas. La app actúa como un **hub de salud integral**.
#
# ---
# ---
#
# ## **📢 PASO 2: Canales de Marketing**
#
# | **Canal** | **Justificación** | **Segmento Objetivo** | **Inversión Estimada (Primeros 3 Meses)** |
# |-----------|-------------------|------------------------|------------------------------------------|
# | **📱 Redes Sociales (Instagram + TikTok)** | Alto engagement en contenido visual (ejercicios, antes/después, historias de éxito). TikTok es clave para llegar a *Gen Z* y *Millennials* (80% de usuarios). Instagram para comunidad y testimonios. | Principiantes, Fitness enthusiasts, Mamás/papás. | $5,000 USD (ads + contenido orgánico). |
# | **🎧 Podcasts y Audio Ads** | El 62% de los usuarios de fitness consumen contenido en formato audio (ej: podcasts de salud, YouTube Audio). Ideal para llegar a profesionales ocupados (ej: "Cómo hacer ejercicio en 15 min"). | Deportistas intermedios, Gimnasio + App. | $3,000 USD (spots en podcasts de nicho). |
# | **🔍 SEO + Google Ads** | El 60% de las búsquedas relacionadas con fitness son informativas ("rutinas para principiantes", "cómo perder grasa"). Google Ads captura usuarios con intención de compra. | Todos los segmentos (especialmente principiantes). | $4,000 USD (keywords + landing pages). |
# | **🤝 Influencers y Microinfluencers** | Los influencers fitness tienen tasas de conversión del **3-5%** (vs. 1% de ads tradicionales). Microinfluencers (10K-100K seguidores) tienen mayor engagement y nichos específicos (ej: "Yoga para mamás", "Entrenamiento para runners"). | Principiantes, Fitness enthusiasts. | $6,000 USD (10-15 colaboraciones). |
# | **📧 Email Marketing + WhatsApp** | Automatización para onboarding (ej: "Bienvenida, aquí tienes tu plan de 7 días gratis"). WhatsApp Business para soporte rápido y retargeting ("¡Hoy es tu día 3! ¿Necesitas un recordatorio?"). | Todos los segmentos (alta retención). | $2,000 USD (herramientas como Mailchimp + WhatsApp API). |
#
# ---
# ---
#
# ## **📝 PASO 3: Estrategia de Contenido**
#
# ### **🎬 Tipos de Contenido por Canal**
#
# | **Canal** | **Tipo de Contenido** | **Frecuencia** | **Ejemplo** |
# |-----------|-----------------------|----------------|-------------|
# | **Instagram** | - Reels (entrenamientos en 15-30 seg). <br> - Carruseles (guías de nutrición). <br> - Stories (polls, Q&A con entrenadores). <br> - Testimonios de usuarios. | 4 Reels/semana <br> 3 Carruseles/semana <br> Stories diarios | Reel: "Entrenamiento de piernas en casa con solo una silla". |
# | **TikTok** | - Desafíos virales (#7DíasDeCardio). <br> - "Before/After" de usuarios. <br> - Humor fitness (ej: "Cuando el entrenador dice 'solo 5 repeticiones más'"). <br> - Lives con entrenadores. | 5-7 videos/semana <br> 2 Lives/mes | Video: "¿Puedes hacer 100 saltos en 1 min? ¡Gana un mes gratis!". |
# | **Podcasts** | - Episodios cortos (10-15 min). <br> - Entrevistas a nutricionistas/entrenadores. <br> - "Mitos del fitness" (ej: "¿El cardio en ayunas quema más grasa?"). | 2 episodios/semana | Episodio: "Cómo volver al gimnasio después de las vacaciones". |
# | **Google Ads** | - Landing pages con CTA claros ("Descarga gratis tu plan de 7 días"). <br> - Anuncios con palabras clave ("rutina para perder barriga", "app de fitness personalizada"). | 10-15 keywords activas <br> A/B testing de landing pages. | Anuncio: "¿Cansado de las mismas rutinas? Prueba [Nombre App] y obtén un plan hecho solo para ti". |
# | **Influencers** | - Unboxings (ej: "Así es la app que usa [Influencer] para sus entrenamientos"). <br> - Retos (ej: "Usa mi código [CÓDIGO] y obtén 20% de descuento"). <br> - Stories con enlaces de afiliado. | 1-2 colaboraciones/mes | Influencer: "Llevo 30 días usando [App] y estos son mis resultados". |
# | **Email Marketing** | - Welcome series (3 emails en 7 días). <br> - Newsletters semanales (tips, descuentos). <br> - Contenido exclusivo (ej: "Plan de entrenamiento para principiantes"). | 1 email/semana <br> Automatizaciones (abandonos de carrito). | Email: "Hola [Nombre], aquí tienes tu plan de 7 días gratis. ¡Empieza hoy!". |
# | **WhatsApp Business** | - Mensajes de recordatorio (ej: "No olvides tu entrenamiento de hoy"). <br> - Soporte en tiempo real. <br> - Encuestas de satisfacción. | 2-3 mensajes/semana <br> Chatbot para FAQs. | Mensaje: "¡Hoy es día 5 de tu desafío! ¿Necesitas un empujón?". |
#
# ---
# ---
#
# ## **📊 PASO 4: Métricas y KPIs**
#
# ### **🎯 5 Métricas Clave (KPIs)**
#
# | **KPI** | **Objetivo** | **Meta (Primeros 3 Meses)** | **HERRAMIENTA** |
# |---------|--------------|-----------------------------|-----------------|
# | **Tasa de Descarga (Conversion Rate)** | % de usuarios que descargan la app tras ver un anuncio o contenido. | **5-10%** (vs. promedio de la industria: 2-3%). | Firebase, Appsflyer. |
# | **Costo por Descarga (CPD)** | Cuánto cuesta adquirir un usuario (incluye ads, influencers, etc.). | **< $2 USD** (meta realista para fitness). | Google Ads, Meta Ads Manager. |
# | **Tasa de Retención al Día 7** | % de usuarios que abren la app 7 días después de descargarla. | **40-50%** (promedio de la industria: 25%). | Mixpanel, Amplitude. |
# | **Tasa de Activación (Usuarios Activos Semanales)** | % de usuarios que completan al menos un entrenamiento en 7 días. | **30-40%** (vs. promedio: 15%). | Google Analytics, Appsflyer. |
# | **Valor de Vida del Cliente (LTV)** | Ingresos promedio que genera un usuario durante su tiempo en la app. | **$15-$30 USD** (con suscripción premium). | Stripe, RevenueCat. |
#
# ---
# ### **🔧 Herramientas de Medición Recomendadas**
#
# | **Categoría** | **Herramienta** | **Uso** |
# |---------------|-----------------|---------|
# | **Analytics de App** | Firebase, Amplitude, Mixpanel | Seguimiento de eventos (ej: "completó entrenamiento", "canceló suscripción"). |
# | **Publicidad Digital** | Google Ads, Meta Ads Manager, TikTok Ads | Métricas de CTR, CPC, conversiones. |
# | **SEO** | Ahrefs, SEMrush, Google Search Console | Palabras clave, tráfico orgánico, backlinks. |
# | **Email Marketing** | Mailchimp, Klaviyo | Tasa de apertura, CTR, conversiones. |
# | **Influencers** | Upfluence, AspireIQ | ROI de colaboraciones, engagement rate. |
# | **Atención al Cliente** | Zendesk, Intercom | Satisfacción del usuario (CSAT, NPS). |
# | **Wearables** | Apple HealthKit, Google Fit API | Integración de datos de salud. |
#
# ---
# ---
#
# ## **🚀 Resumen de la Estrategia (Checklist)**
#
# | **Fase** | **Acciones Clave** | **Plazo** | **Responsable** |
# |----------|--------------------|-----------|-----------------|
# | **Pre-lanzamiento (Mes 0)** | - Definir branding (nombre, logo, tono). <br> - Crear perfiles en redes sociales. <br> - Grabar contenido para el primer mes. <br> - Configurar Firebase + Google Analytics. | 4 semanas | Equipo de Marketing + Diseño. |
# | **Lanzamiento (Mes 1)** | - Campaña de influencers (10-15 colaboraciones). <br> - Lanzar Google Ads y Meta Ads. <br> - Publicar contenido diario en TikTok/Instagram. <br> - Enviar emails de bienvenida. | 4 semanas | Equipo de Marketing + Influencers. |
# | **Post-lanzamiento (Mes 2-3)** | - Analizar métricas y ajustar campañas. <br> - Lanzar desafíos virales en TikTok. <br> - Optimizar SEO con contenido evergreen. <br> - Implementar WhatsApp Business. | 8 semanas | Equipo de Marketing + Data Analyst. |
# | **Escalamiento (Mes 4+)** | - Expandir a nuevos mercados (ej: Latinoamérica). <br> - Lanzar versión premium con más features. <br> - Crear programa de referidos ("Trae a un amigo y gana 1 mes gratis"). | En curso | Equipo de Producto + Marketing. |
#
# ---
# ---
#
# ## **💡 Conclusión: Claves del Éxito**
#
# 1. **Enfoque en el usuario:** La IA personalizada y la comunidad son los diferenciadores clave. Usa datos de los primeros 30 días para refinar las recomendaciones.
# 2. **Contenido viral:** TikTok y Reels deben dominar la estrategia orgánica (70% del tráfico inicial puede venir de ahí).
# 3. **Retención > Adquisición:** Una retención del 40% al día 7 es excelente. Usa WhatsApp y emails para mantener el engagement.
# 4. **Métricas en tiempo real:** Ajusta el gasto en ads según el CPD y la retención. Si un canal tiene CPD alto pero baja retención, redirige el presupuesto.
# 5. **Comunidad antes que ventas:** Los testimonios orgánicos (user-generated content) tienen **3x más conversión** que los anuncios tradicionales.
#
# ---
# **🔥 Pro Tip Final:**
# - **Prueba A/B todo:** Desde los colores de los botones en la landing page hasta el horario de publicación en Instagram.
# - **Monitoriza a la competencia:** Usa herramientas como **App Annie** o **Sensor Tower** para ver qué funciona en apps similares.
# - **Prepara un plan de crisis:** Si hay críticas en redes (ej: "La app no funciona con mi Apple Watch"), responde en menos de 2 horas con una solución.
#
# ---
# **¿Listo para lanzar? 🚀**
# Si necesitas profundizar en algún área (ej: cómo estructurar las campañas de influencers o el flujo de onboarding en la app), dime y te doy un desglose más detallado.
#
# === ANÁLISIS DE ESTRUCTURA ===
# • Pasos identificados: 4/4
# • Secciones cubiertas: 4/4
# • Estructura seguida: ✓

# %% [markdown]
# ## Casos de Uso Avanzados
#
# Aplicaciones más sofisticadas de zero-shot prompting.

# %%
# Caso de uso: Análisis de código
def analisis_codigo_zero_shot():
    print("=== CASO DE USO: ANÁLISIS DE CÓDIGO ===")

    codigo_ejemplo = '''def process_user_data(users):
    result = []
    for user in users:
        if user["age"] > 18:
            result.append({
                "name": user["name"].upper(),
                "email": user["email"],
                "status": "adult"
            })
    return result'''

    prompt_analisis = f"""Eres un senior code reviewer con experiencia en Python.

Analiza el siguiente código y proporciona:

1. FUNCIONALIDAD:
   - ¿Qué hace este código?
   - ¿Cuál es su propósito?

2. PROBLEMAS POTENCIALES:
   - Errores de lógica
   - Vulnerabilidades de seguridad
   - Problemas de rendimiento

3. MEJORAS SUGERIDAS:
   - Optimizaciones de código
   - Mejores prácticas
   - Manejo de errores

4. PUNTUACIÓN DE CALIDAD: [1-10]

Código a analizar:
```python
{codigo_ejemplo}
```

Análisis:"""

    try:
        response = llm.invoke([HumanMessage(content=prompt_analisis)])
        print("ANÁLISIS DE CÓDIGO:")
        print("=" * 50)
        print(response.content)

    except Exception as e:
        print(f"Error: {e}")

# Ejecutar análisis de código
analisis_codigo_zero_shot()
# Out:
# === CASO DE USO: ANÁLISIS DE CÓDIGO ===
# ANÁLISIS DE CÓDIGO:
# ==================================================
# ### **ANÁLISIS DEL CÓDIGO**
#
# ---
#
# #### **1. FUNCIONALIDAD**
#
# **¿Qué hace este código?**
# - La función `process_user_data(users)` recibe una lista de diccionarios (`users`), donde cada diccionario representa un usuario con al menos las claves `"name"`, `"email"` y `"age"`.
# - Para cada usuario, verifica si su edad (`"age"`) es mayor que 18.
# - Si la condición se cumple, crea un nuevo diccionario con:
#   - `"name"` convertido a mayúsculas.
#   - `"email"` sin modificar.
#   - `"status"` fijo en `"adult"`.
# - Finalmente, devuelve una lista con los usuarios que cumplen la condición.
#
# **Propósito:**
# - Filtrar usuarios mayores de edad y transformar sus datos para un formato específico (ejemplo: normalización de nombres, etiquetado de estado).
# - Podría usarse en un contexto de autenticación, generación de reportes, o procesamiento de datos para APIs.
#
# ---
#
# #### **2. PROBLEMAS POTENCIALES**
#
# ##### **Errores de Lógica**
# 1. **Falta validación de claves obligatorias:**
#    - Si algún usuario no tiene `"age"`, `"name"` o `"email"`, el código lanzará un `KeyError`.
#    - Si `"age"` no es un número (ej. `None`, `"twenty"`), habrá un error en la comparación `> 18`.
#
# 2. **No maneja usuarios con edad exactamente 18:**
#    - La condición `age > 18` excluye a los usuarios de 18 años, lo que podría ser intencional o no según el requisito de negocio.
#
# 3. **Asume que el formato de `email` es correcto:**
#    - No valida el formato del email (ej. `"usuario@dominio.com"`).
#
# 4. **No maneja casos nulos o vacíos:**
#    - Si `users` es `None` o una lista vacía, el código funciona, pero si un usuario tiene `user = None`, se generará un error.
#
# ##### **Vulnerabilidades de Seguridad**
# 1. **Inyección de datos en `name`:**
#    - Si `user["name"]` contiene caracteres especiales (ej. `"<script>alert('xss')</script>"`), y el resultado se usa en un contexto web sin sanitización, podría haber vulnerabilidades XSS.
#
# 2. **Falta de control de acceso:**
#    - No hay verificación de permisos (ej. si el usuario tiene derecho a acceder a estos datos).
#
# 3. **Exposición de datos sensibles:**
#    - Si el `email` se usa en una respuesta HTTP sin cifrado, podría exponerse información sensible.
#
# ##### **Problemas de Rendimiento**
# 1. **Ineficiencia en listas grandes:**
#    - Para cada usuario, se crea un nuevo diccionario y se realiza una operación de `.upper()`, lo que puede ser costoso en memoria y CPU si `users` es muy grande.
#    - No hay manejo de streaming o procesamiento por lotes.
#
# 2. **No usa comprensiones de lista:**
#    - El código actual es más legible, pero para datos grandes, una comprensión de lista (`[... for ... if ...]`) sería más eficiente.
#
# ---
#
# #### **3. MEJORAS SUGERIDAS**
#
# ##### **1. Validación y Manejo de Errores**
# ```python
# def process_user_data(users):
#     if not isinstance(users, list):
#         raise ValueError("Input must be a list of users")
#
#     result = []
#     for user in users:
#         try:
#             if not isinstance(user, dict):
#                 continue  # Opcional: saltar usuarios no válidos
#
#             age = user["age"]
#             if not isinstance(age, (int, float)) or age < 0:
#                 continue  # Saltar edades inválidas
#
#             name = user.get("name", "").strip()
#             email = user.get("email", "").strip()
#
#             if not name or not email:
#                 continue  # Saltar nombres o emails vacíos
#
#             # Validación básica de email (opcional)
#             if "@" not in email:
#                 continue
#
#             if age >= 18:  # Cambiado de > 18 a >= 18 si se quiere incluir 18 años
#                 result.append({
#                     "name": name.upper(),
#                     "email": email,
#                     "status": "adult"
#                 })
#         except (KeyError, TypeError):
#             continue  # Saltar usuarios con datos faltantes o corruptos
#
#     return result
# ```
#
# ##### **2. Optimización con Comprensión de Lista**
# ```python
# def process_user_data(users):
#     if not isinstance(users, list):
#         raise ValueError("Input must be a list of users")
#
#     return [
#         {
#             "name": name.upper(),
#             "email": email,
#             "status": "adult"
#         }
#         for user in users
#         if (
#             isinstance(user, dict) and
#             (age := user.get("age")) is not None and
#             isinstance(age, (int, float)) and
#             age >= 18 and
#             (name := user.get("name", "").strip()) and
#             (email := user.get("email", "").strip()) and
#             "@" in email
#         )
#     ]
# ```
#
# ##### **3. Mejoras Adicionales**
# - **Tipado estático (usando `typing`):**
#   ```python
#   from typing import List, Dict
#
#   User = Dict[str, str | int]
#   def process_user_data(users: List[User]) -> List[Dict[str, str]]:
#       ...
#   ```
# - **Uso de `dataclasses` para estructuras de datos:**
#   ```python
#   from dataclasses import dataclass
#
#   @dataclass
#   class ProcessedUser:
#       name: str
#       email: str
#       status: str
#   ```
# - **Logging para depuración:**
#   ```python
#   import logging
#   logging.basicConfig(level=logging.INFO)
#   logging.info(f"Processed {len(result)} adult users.")
#   ```
# - **Sanitización de `name` para XSS:**
#   ```python
#   from html import escape
#   "name": escape(name.upper())  # Si el resultado se usa en HTML
#   ```
#
# ---
#
# #### **4. PUNTUACIÓN DE CALIDAD: [4/10]**
#
# **Explicación:**
# - **Puntos positivos:**
#   - Código simple y fácil de entender.
#   - Cumple con su propósito básico.
# - **Puntos negativos:**
#   - **Falta manejo de errores** (crashes con datos inválidos).
#   - **No es robusto** (asume estructura de datos perfecta).
#   - **Rendimiento subóptimo** para grandes volúmenes.
#   - **Seguridad débil** (riesgo de XSS, exposición de datos).
#   - **No sigue principios SOLID** (ej. responsabilidad única si se amplía funcionalidad).
#
# **Puntuación mejorada:**
# Con las mejoras sugeridas, la puntuación subiría a **8-9/10**.
#
# ---
#
# ### **RESUMEN FINAL**
# | **Categoría**       | **Evaluación**                                                                 |
# |----------------------|-------------------------------------------------------------------------------|
# | **Funcionalidad**    | ✅ Cumple su propósito, pero con limitaciones en validación.                 |
# | **Seguridad**        | ❌ Riesgo de XSS y exposición de datos.                                       |
# | **Rendimiento**      | ⚠️ Ineficiente para grandes listas.                                            |
# | **Mantenibilidad**   | ⚠️ Código frágil (depende de estructura exacta de `users`).                   |
# | **Manejo de Errores**| ❌ No maneja casos edge (datos faltantes, tipos incorrectos).                 |
#
# **Recomendación principal:**
# Refactorizar el código para incluir validación, manejo de errores y sanitización, especialmente si se usa en producción o con datos externos.

# %%
# Caso de uso: Generación de tests
def generacion_tests_zero_shot():
    print("=== CASO DE USO: GENERACIÓN DE TESTS ===")

    funcion_a_testear = '''def calculate_discount(price, discount_percent, user_type):
    """Calculate final price after discount.

    Args:
        price (float): Original price
        discount_percent (float): Discount percentage (0-100)
        user_type (str): 'premium' or 'regular'

    Returns:
        float: Final price after discount
    """
    if user_type == 'premium':
        discount_percent += 5  # Extra 5% for premium users

    discount_amount = price * (discount_percent / 100)
    return price - discount_amount'''

    prompt_tests = f"""Eres un QA engineer experto en testing de Python.

Genera tests unitarios completos para la siguiente función usando pytest.

Incluye tests para:
1. Casos normales (diferentes tipos de usuario y descuentos)
2. Casos edge (descuento 0%, 100%, valores negativos)
3. Casos de error (tipos incorrectos, valores inválidos)
4. Tests parametrizados cuando sea apropiado

Función a testear:
```python
{funcion_a_testear}
```

Genera código de test completo y ejecutable:"""

    try:
        response = llm.invoke([HumanMessage(content=prompt_tests)])
        print("TESTS GENERADOS:")
        print("=" * 50)
        print(response.content)

        # Análisis básico de los tests generados
        test_methods = response.content.count("def test_")
        assertions = response.content.count("assert")
        parametrize = response.content.count("@pytest.mark.parametrize")

        print("\n=== ANÁLISIS DE TESTS ===")
        print(f"• Métodos de test: {test_methods}")
        print(f"• Assertions: {assertions}")
        print(f"• Tests parametrizados: {parametrize}")
        print(f"• Cobertura estimada: {'Alta' if test_methods >= 5 else 'Media' if test_methods >= 3 else 'Baja'}")

    except Exception as e:
        print(f"Error: {e}")

# Ejecutar generación de tests
generacion_tests_zero_shot()
# Out:
# === CASO DE USO: GENERACIÓN DE TESTS ===
# TESTS GENERADOS:
# ==================================================
# # Tests Unitarios para `calculate_discount` con pytest
#
# Aquí tienes un conjunto completo de tests unitarios para la función `calculate_discount` usando pytest. Incluyo pruebas para casos normales, edge cases, casos de error y pruebas parametrizadas:
#
# ```python
# import pytest
# from unittest.mock import patch
# from your_module import calculate_discount  # Ajusta el import según tu estructura de proyecto
#
# class TestCalculateDiscount:
#     """Test suite for calculate_discount function"""
#
#     # ========== Casos Normales ==========
#     def test_regular_user_normal_discount(self):
#         """Test normal discount for regular user"""
#         result = calculate_discount(100.0, 10.0, 'regular')
#         assert result == 90.0
#
#     def test_premium_user_normal_discount(self):
#         """Test normal discount for premium user (with extra 5%)"""
#         result = calculate_discount(100.0, 10.0, 'premium')
#         assert result == 85.0  # 100 - (15% of 100)
#
#     def test_premium_user_high_discount(self):
#         """Test premium user with high discount percentage"""
#         result = calculate_discount(200.0, 30.0, 'premium')
#         assert result == 130.0  # 200 - (35% of 200)
#
#     def test_regular_user_zero_discount(self):
#         """Test regular user with 0% discount"""
#         result = calculate_discount(50.0, 0.0, 'regular')
#         assert result == 50.0
#
#     def test_premium_user_zero_discount(self):
#         """Test premium user with 0% discount (should get 5% extra)"""
#         result = calculate_discount(50.0, 0.0, 'premium')
#         assert result == 47.5  # 50 - (5% of 50)
#
#     # ========== Edge Cases ==========
#     def test_discount_100_percent(self):
#         """Test 100% discount for both user types"""
#         regular_result = calculate_discount(100.0, 100.0, 'regular')
#         premium_result = calculate_discount(100.0, 100.0, 'premium')
#
#         assert regular_result == 0.0
#         assert premium_result == -5.0  # 100 - (105% of 100) = -5
#
#     def test_discount_above_100_percent(self):
#         """Test discount above 100% (should still work but result in negative price)"""
#         result = calculate_discount(100.0, 150.0, 'regular')
#         assert result == -50.0  # 100 - (150% of 100)
#
#     def test_negative_price(self):
#         """Test negative price (should work mathematically but might not be business logic)"""
#         result = calculate_discount(-100.0, 10.0, 'regular')
#         assert result == -90.0  # -100 - (10% of -100)
#
#     def test_premium_user_with_negative_price(self):
#         """Test premium user with negative price"""
#         result = calculate_discount(-100.0, 10.0, 'premium')
#         assert result == -95.0  # -100 - (15% of -100)
#
#     # ========== Casos de Error ==========
#     def test_invalid_user_type(self):
#         """Test invalid user type (should raise ValueError or similar)"""
#         with pytest.raises(ValueError, match="Invalid user type"):
#             calculate_discount(100.0, 10.0, 'invalid')
#
#     def test_string_price(self):
#         """Test string price (should raise TypeError)"""
#         with pytest.raises(TypeError, match="price must be a number"):
#             calculate_discount("100.0", 10.0, 'regular')
#
#     def test_string_discount(self):
#         """Test string discount percentage (should raise TypeError)"""
#         with pytest.raises(TypeError, match="discount_percent must be a number"):
#             calculate_discount(100.0, "10", 'regular')
#
#     def test_none_values(self):
#         """Test None values (should raise TypeError)"""
#         with pytest.raises(TypeError, match="None is not a valid value"):
#             calculate_discount(None, 10.0, 'regular')
#
#     def test_missing_arguments(self):
#         """Test missing arguments (should raise TypeError)"""
#         with pytest.raises(TypeError):
#             calculate_discount(100.0, 10.0)  # missing user_type
#
#     # ========== Tests Parametrizados ==========
#     @pytest.mark.parametrize("price, discount, user_type, expected", [
#         (100.0, 0.0, 'regular', 100.0),
#         (100.0, 0.0, 'premium', 95.0),
#         (100.0, 50.0, 'regular', 50.0),
#         (100.0, 50.0, 'premium', 45.0),
#         (1000.50, 25.5, 'regular', 749.625),
#         (1000.50, 25.5, 'premium', 712.125),
#         (0.0, 10.0, 'regular', 0.0),
#         (0.0, 10.0, 'premium', 0.0),
#     ])
#     def test_parametrized_normal_cases(self, price, discount, user_type, expected):
#         """Parametrized test for various normal cases"""
#         result = calculate_discount(price, discount, user_type)
#         assert result == expected
#
#     @pytest.mark.parametrize("price, discount, user_type", [
#         (-100.0, 10.0, 'regular'),
#         (100.0, -10.0, 'regular'),
#         (100.0, 110.0, 'premium'),
#         (100.0, '10', 'regular'),
#         ('100', 10.0, 'regular'),
#         (100.0, 10.0, 123),
#         (None, 10.0, 'regular'),
#         (100.0, None, 'regular'),
#         (100.0, 10.0, None),
#     ])
#     def test_parametrized_error_cases(self, price, discount, user_type):
#         """Parametrized test for error cases"""
#         with pytest.raises((TypeError, ValueError)):
#             calculate_discount(price, discount, user_type)
#
#     # ========== Tests Adicionales (si se modifica la función) ==========
#     @patch('your_module.calculate_discount')
#     def test_side_effects(self, mock_calc):
#         """Test that the function doesn't have unwanted side effects"""
#         # Reset any potential state modifications
#         mock_calc.return_value = 0
#         result = calculate_discount(100.0, 10.0, 'regular')
#         mock_calc.assert_called_once_with(100.0, 10.0, 'regular')
#         assert result == 0
# ```
#
# ## Notas importantes:
#
# 1. **Ajuste de imports**: Cambia `your_module` por el nombre real de tu módulo donde está definida la función.
#
# 2. **Validación de tipos**: La función original no valida los tipos de entrada. En los tests he incluido casos donde debería fallar si se implementa validación. Si no se valida, estos tests fallarán.
#
# 3. **Comportamiento esperado**: La función actual no valida que `user_type` sea solo 'premium' o 'regular'. Si quieres que falle con otros valores, necesitarías modificar la función para incluir esa validación.
#
# 4. **Cobertura**: Estos tests cubren:
#    - Diferentes tipos de usuarios
#    - Diferentes porcentajes de descuento
#    - Casos edge (0%, 100%, valores negativos)
#    - Casos de error (tipos incorrectos, valores nulos)
#    - Pruebas parametrizadas para evitar repetición
#
# 5. **Recomendación**: Si la función se va a usar en producción, considera añadir validación para:
#    - Precios negativos (¿deberían estar permitidos?)
#    - Porcentajes de descuento por encima de 100%
#    - Tipos de usuario inválidos
#
# 6. **Ejecución**: Guarda estos tests en un archivo `test_calculate_discount.py` y ejecútalos con:
#    ```bash
#    pytest test_calculate_discount.py -v
#    ```
#
# === ANÁLISIS DE TESTS ===
# • Métodos de test: 17
# • Assertions: 13
# • Tests parametrizados: 2
# • Cobertura estimada: Alta

# %% [markdown]
# ## Mejores Prácticas y Limitaciones
#
# ### ✅ Cuándo Usar Zero-Shot:
# - Tareas comunes y bien definidas
# - Cuando no tienes ejemplos disponibles
# - Para prototipado rápido
# - Tareas que requieren creatividad
#
# ### ❌ Cuándo NO Usar Zero-Shot:
# - Formatos de salida muy específicos
# - Tareas de dominio muy especializado
# - Cuando la consistencia es crítica
# - Tareas complejas que requieren patrones específicos
#
# ### 🎯 Mejores Prácticas:
# 1. **Sé específico**: Detalla exactamente qué quieres
# 2. **Define el formato**: Especifica cómo debe verse la salida
# 3. **Establece restricciones**: Qué debe evitar o considerar
# 4. **Usa roles**: Define quién debe "ser" el modelo
# 5. **Itera y refina**: Mejora basándote en resultados

# %%
# Ejercicio final: Diseña tu propio prompt zero-shot
def ejercicio_personalizado():
    print("=== EJERCICIO PERSONAL ===")
    print("\nDiseña un prompt zero-shot para esta tarea:")
    print("'Crear una descripción de trabajo atractiva para un puesto de desarrollador Python junior'")
    print("\nEstructura sugerida:")
    print("1. Rol/Contexto del modelo")
    print("2. Tarea específica")
    print("3. Requisitos del formato")
    print("4. Restricciones importantes")
    print("\nTu prompt aquí:")

    # Espacio para que el estudiante diseñe su prompt
    prompt_estudiante = """# COLOCA TU PROMPT AQUÍ

# Ejemplo de estructura:
# Eres un [ROL]...
# Tarea: [TAREA ESPECÍFICA]...
# Formato: [ESTRUCTURA DE SALIDA]...
# Restricciones: [LIMITACIONES]...
"""

    print(prompt_estudiante)

    # Prompt de ejemplo bien estructurado
    ejemplo_prompt = """Eres un HR Business Partner senior especializado en tecnología con 8 años de experiencia reclutando desarrolladores.

Tarea: Redacta una descripción de trabajo atractiva y realista para un puesto de Desarrollador Python Junior.

Formato requerido:
- Título del puesto
- Resumen ejecutivo (2-3 líneas)
- Responsabilidades principales (4-5 puntos)
- Requisitos técnicos (separar esenciales de deseables)
- Beneficios y cultura de empresa
- Llamada a la acción

Restricciones:
- Máximo 400 palabras
- Lenguaje inclusivo y accesible
- Enfócate en crecimiento profesional
- Evita jerga técnica excesiva
- Sé honesto sobre el nivel junior

Descripción de trabajo:"""

    print("\n=== EJEMPLO DE PROMPT BIEN ESTRUCTURADO ===")
    print(ejemplo_prompt)

    # Opcional: probar el prompt ejemplo
    print("\n¿Quieres ver el resultado del prompt ejemplo? (y/n)")
    # En un entorno real, aquí habría input del usuario

ejercicio_personalizado()
# Out:
# === EJERCICIO PERSONAL ===
#
# Diseña un prompt zero-shot para esta tarea:
# 'Crear una descripción de trabajo atractiva para un puesto de desarrollador Python junior'
#
# Estructura sugerida:
# 1. Rol/Contexto del modelo
# 2. Tarea específica
# 3. Requisitos del formato
# 4. Restricciones importantes
#
# Tu prompt aquí:
# # COLOCA TU PROMPT AQUÍ
#
# # Ejemplo de estructura:
# # Eres un [ROL]...
# # Tarea: [TAREA ESPECÍFICA]...
# # Formato: [ESTRUCTURA DE SALIDA]...
# # Restricciones: [LIMITACIONES]...
#
#
# === EJEMPLO DE PROMPT BIEN ESTRUCTURADO ===
# Eres un HR Business Partner senior especializado en tecnología con 8 años de experiencia reclutando desarrolladores.
#
# Tarea: Redacta una descripción de trabajo atractiva y realista para un puesto de Desarrollador Python Junior.
#
# Formato requerido:
# - Título del puesto
# - Resumen ejecutivo (2-3 líneas)
# - Responsabilidades principales (4-5 puntos)
# - Requisitos técnicos (separar esenciales de deseables)
# - Beneficios y cultura de empresa
# - Llamada a la acción
#
# Restricciones:
# - Máximo 400 palabras
# - Lenguaje inclusivo y accesible
# - Enfócate en crecimiento profesional
# - Evita jerga técnica excesiva
# - Sé honesto sobre el nivel junior
#
# Descripción de trabajo:
#
# ¿Quieres ver el resultado del prompt ejemplo? (y/n)

# %% [markdown]
# ## Conceptos Clave Aprendidos
#
# 1. **Zero-shot prompting** es efectivo para tareas comunes sin necesidad de ejemplos
# 2. **Estructura clara** del prompt mejora significativamente los resultados
# 3. **Roles específicos** generan respuestas más enfocadas y expertas
# 4. **Instrucciones graduales** ayudan con tareas complejas
# 5. **Formato definido** asegura salidas consistentes y útiles
#
# ## Próximos Pasos
#
# En el siguiente notebook exploraremos **Few-Shot Prompting**, donde aprenderemos a usar ejemplos específicos para guiar el comportamiento del modelo y lograr mayor consistencia en tareas especializadas.
#
# ### Para Practicar:
# 1. Diseña prompts zero-shot para diferentes tipos de tareas
# 2. Experimenta con diferentes roles y contextos
# 3. Compara resultados con y sin estructura específica
# 4. Mide la consistencia en múltiples ejecuciones
