# %% [markdown]
# [![Abrir en Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/fvalenzuelag/Ingenier-a-de-Soluciones-con-Inteligencia-Artificial/blob/Mistral/RA1/IL1.2/1-zero-shot-prompting.ipynb)

# %% [markdown]
# # 1. Zero-Shot Prompting - Prompts Sin Ejemplos Previos
#
# ## Objetivos de Aprendizaje
# - Comprender los principios del zero-shot prompting
# - Diseñar prompts efectivos sin ejemplos previos
# - Aplicar técnicas de instrucción clara y contexto
# - Evaluar la efectividad de diferentes enfoques zero-shot
#
# ## ¿Qué es Zero-Shot Prompting?
#
# Zero-shot prompting es la técnica donde pedimos al modelo realizar una tarea **sin proporcionar ejemplos específicos** de cómo debe hacerla. El modelo debe basarse únicamente en:
# - Su entrenamiento previo
# - Las instrucciones que le damos
# - El contexto que proporcionamos
#
# ### Ventajas:
# - **Simplicidad**: No requiere crear ejemplos
# - **Flexibilidad**: Fácil de adaptar a nuevas tareas
# - **Eficiencia**: Menos tokens utilizados
# - **Generalización**: Funciona para tareas diversas
#
# ### Limitaciones:
# - **Inconsistencia**: Resultados pueden variar más
# - **Formato**: Menos control sobre la estructura de salida
# - **Tareas complejas**: Puede requerir instrucciones muy detalladas
# - **Dominio específico**: Menos efectivo en nichos especializados

# %%
# --- Instalación de dependencias (se ejecuta solo en Google Colab) ---
# En local no hace nada: usa `pip install -r requirements.txt` desde la raíz del repo.
import sys
if "google.colab" in sys.modules:
    # !pip install -q langchain langchain-classic langchain-openai python-dotenv

# %%
# --- Credenciales: funciona en local (.env) y en Google Colab (Secrets) ---
import os
try:
    from google.colab import userdata          # Colab: panel 🔑 Secrets
    # Solo LLM_API_KEY es obligatorio. Los demás son opcionales: defínelos como
    # Secrets únicamente si quieres usar otro proveedor o modelo.
    for _k in ("LLM_API_KEY", "GOOGLE_API_KEY", "LANGSMITH_API_KEY",
               "LLM_BASE_URL", "LLM_MODEL", "LLM_MODEL_SMALL"):
        try:
            os.environ[_k] = userdata.get(_k)
        except Exception:
            pass                                # el Secret no existe: se usa el default
    os.environ.setdefault("LLM_BASE_URL", "https://api.mistral.ai/v1")
    os.environ.setdefault("LLM_MODEL", "mistral-small-latest")
    os.environ.setdefault("LLM_MODEL_SMALL", "ministral-8b-latest")
except ImportError:
    from dotenv import load_dotenv             # Local: archivo .env en la raíz
    load_dotenv()

# Configuración inicial
from langchain_openai import ChatOpenAI
# LangChain v1: langchain_core.messages / langchain_core.documents
from langchain_classic.schema import HumanMessage, SystemMessage
import os
import time

# Configurar el modelo
llm = ChatOpenAI(
    base_url=os.getenv("LLM_BASE_URL"),
    api_key=os.getenv("LLM_API_KEY"),
    model=os.getenv("LLM_MODEL", "mistral-small-latest"),
    temperature=0.7  # Balance entre creatividad y consistencia
)

print("✓ Modelo configurado para zero-shot prompting")
# Out:
# ✓ Modelo configurado para zero-shot prompting

# %% [markdown]
# ## Anatomía de un Prompt Zero-Shot Efectivo
#
# Un prompt zero-shot efectivo tiene estos componentes:
#
# 1. **Contexto/Rol**: Quién debe "ser" el modelo
# 2. **Tarea**: Qué debe hacer específicamente
# 3. **Formato**: Cómo debe estructurar la respuesta
# 4. **Restricciones**: Qué debe evitar o considerar
# 5. **Input**: Los datos específicos a procesar

# %%
# Ejemplo básico vs mejorado
def comparar_prompts_basico():
    texto = "El nuevo iPhone tiene una batería increíble y la cámara es fantástica, pero el precio es muy Bajo."

    # Prompt básico (menos efectivo)
    prompt_basico = f"Analiza este texto: {texto}"

    # Prompt mejorado (más efectivo)
    prompt_mejorado = f"""Eres un analista de sentimientos experto.

Tarea: Analiza el sentimiento del siguiente texto sobre un producto.

Formato de respuesta:
- Sentimiento general: [Positivo/Negativo/Neutral]
- Aspectos positivos: [lista]
- Aspectos negativos: [lista]
- Puntuación de confianza: [0-10]

Texto a analizar: "{texto}"""

    print("=== COMPARACIÓN DE PROMPTS ===")

    # Probar prompt básico
    print("\n1. PROMPT BÁSICO:")
    print(f"Prompt: {prompt_basico}")
    try:
        response1 = llm.invoke([HumanMessage(content=prompt_basico)])
        print(f"Respuesta: {response1.content}")
    except Exception as e:
        print(f"Error: {e}")

    print("\n" + "-"*60)

    # Probar prompt mejorado
    print("\n2. PROMPT MEJORADO:")
    print(f"Prompt: {prompt_mejorado[:100]}...")
    try:
        response2 = llm.invoke([HumanMessage(content=prompt_mejorado)])
        print(f"Respuesta: {response2.content}")
    except Exception as e:
        print(f"Error: {e}")

    print("\n=== ANÁLISIS ===")
    print("• Prompt básico: Ambiguo, respuesta poco estructurada")
    print("• Prompt mejorado: Específico, respuesta estructurada y útil")

# Ejecutar comparación
comparar_prompts_basico()
# Out:
# === COMPARACIÓN DE PROMPTS ===
#
# 1. PROMPT BÁSICO:
# Prompt: Analiza este texto: El nuevo iPhone tiene una batería increíble y la cámara es fantástica, pero el precio es muy alto.
# Respuesta: El texto es **breve, claro y directo**, típico de una reseña o comentario sobre un producto. Aquí hay un análisis detallado de sus características:
#
# ---
#
# ### **1. Estructura y contenido**
# - **Formato**: Dos frases simples conectadas por una conjunción adversativa (*"pero"*), lo que refleja una opinión equilibrada.
# - **Estructura**:
#   - **Primera parte** (positiva):
#     *"El nuevo iPhone tiene una batería increíble y la cámara es fantástica"*.
#     - **Enfoque**: Destaca **dos aspectos técnicos** destacados del producto (batería y cámara).
#     - **Adjetivos valorativos**: *"increíble"* y *"fantástica"* transmiten entusiasmo y subjetividad.
#   - **Segunda parte** (negativa):
#     *"pero el precio es muy alto"*.
#     - **Contraste**: Usa el *"pero"* para introducir una crítica, equilibrando la valoración positiva.
#     - **Adjetivo valorativo**: *"muy alto"* refuerza la idea de que el precio es un inconveniente.
#
# ---
#
# ### **2. Lenguaje y estilo**
# - **Léxico**:
#   - **Técnico**: Menciona elementos concretos ("batería", "cámara", "precio"), lo que sugiere que el autor es conocedor del producto.
#   - **Emotivo**: Los adjetivos (*increíble, fantástica, alto*) revelan una **opinión personal**, no solo datos objetivos.
# - **Sintaxis**:
#   - **Oraciones simples y coordinadas**, lo que facilita la lectura rápida.
#   - **Conector adversativo (*"pero"*)**: Marca un contraste claro entre lo positivo y lo negativo.
#
# ---
# ### **3. Contexto y propósito**
# - **Posible origen**:
#   - **Reseña de usuario** (en redes sociales, tiendas como Amazon o foros).
#   - **Artículo breve** (blog o medio tecnológico).
# - **Propósito**:
#   - **Informar**: Destacar las mejoras del nuevo iPhone.
#   - **Opinar**: Criticar el precio como un punto débil.
#   - **Persuadir**: Podría influir en la decisión de compra de otros consumidores.
#
# ---
# ### **4. Puntos fuertes y débiles**
# | **Fortalezas**                          | **Debilidades**                          |
# |-----------------------------------------|------------------------------------------|
# | **Claridad**: Mensaje fácil de entender. | **Subjetividad**: No hay datos concretos (ej.: duración real de la batería, megapíxeles de la cámara). |
# | **Equilibrio**: Muestra pros y contras. | **Generalización**: Frases como *"increíble"* o *"muy alto"* son relativas. |
# | **Concisión**: Ideal para redes sociales. | **Falta de contexto**: No especifica modelo ni compara con versiones anteriores. |
#
# ---
# ### **5. Mejoras posibles (si el objetivo es más persuasivo o informativo)**
# - **Añadir datos concretos**:
#   *"La batería dura hasta 20 horas en reproducción de video (según Apple), y la cámara de 48 MP captura detalles nítidos. Sin embargo, con un precio de $1,200, está fuera del alcance de muchos."*
# - **Incluir comparativas**:
#   *"Supera a sus competidores en fotografía, pero modelos como el [Xiaomi Y3] ofrecen características similares por la mitad de precio."*
# - **Usar un tono más objetivo**:
#   En lugar de *"increíble"*, podría decir: *"La batería tiene un 20% más de autonomía que el modelo anterior."*
#
# ---
# ### **6. Conclusión**
# El texto es **efectivo para un comentario rápido o informal**, pero carece de profundidad analítica. Su fuerza radica en:
# - **Ser directo y fácil de digerir**.
# - **Reflejar una opinión equilibrada** (no todo es perfecto).
# - **Usar lenguaje emotivo** para conectar con otros consumidores.
#
# **Ejemplo de adaptación para un análisis más técnico**:
# *"El nuevo iPhone destaca por su batería de larga duración (hasta 20 horas según pruebas) y su cámara de 48 MP, que mejora notablemente la calidad de las fotos. No obstante, su precio de lanzamiento (1,200 USD) lo sitúa como un producto premium, lo que limita su accesibilidad para un público más amplio."*
#
# ---
# ¿Te gustaría profundizar en algún aspecto en particular, como el tono, el público objetivo o posibles variaciones del texto?
#
# ------------------------------------------------------------
#
# 2. PROMPT MEJORADO:
# Prompt: Eres un analista de sentimientos experto.
#
# Tarea: Analiza el sentimiento del siguiente texto sobre ...
# Respuesta: - **Sentimiento general:** Neutral (con tendencia positiva)
# - **Aspectos positivos:**
#   - Batería de alta calidad ("increíble").
#   - Cámara de excelente rendimiento ("fantástica").
# - **Aspectos negativos:**
#   - Precio elevado ("muy alto").
# - **Puntuación de confianza:** 9/10 (el análisis es claro y basado en afirmaciones explícitas, aunque podría requerir contexto adicional para una valoración más precisa).
#
# === ANÁLISIS ===
# • Prompt básico: Ambiguo, respuesta poco estructurada
# • Prompt mejorado: Específico, respuesta estructurada y útil

# %% [markdown]
# ## Técnicas de Zero-Shot por Tipo de Tarea
#
# Diferentes tipos de tareas requieren enfoques específicos en zero-shot prompting.

# %%
# 1. CLASIFICACIÓN
def zero_shot_clasificacion():
    print("=== ZERO-SHOT PARA CLASIFICACIÓN ===")

    emails = [
        "Reunión de equipo mañana a las 10 AM en sala de conferencias",
        "¡Felicidades! Has ganado $1,000,000! Haz clic aquí ahora",
        "Recordatorio: Tu factura de internet vence en 3 días"
    ]

    # Prompt optimizado para clasificación
    clasificacion_prompt = """Eres un clasificador de emails empresariales.

Clasifica cada email en una de estas categorías:
- TRABAJO: Relacionado con tareas laborales
- SPAM: Contenido no solicitado o sospechoso
- PERSONAL: Asuntos personales o administrativos

Responde solo con el nombre de la categoría.

Email: "{}"
Categoría:"""

    for i, email in enumerate(emails, 1):
        prompt = clasificacion_prompt.format(email)
        try:
            response = llm.invoke([HumanMessage(content=prompt)])
            print(f"{i}. Email: {email[:50]}...")
            print(f"   Clasificación: {response.content.strip()}\n")
        except Exception as e:
            print(f"Error en email {i}: {e}")

# Ejecutar clasificación
zero_shot_clasificacion()
# Out:
# === ZERO-SHOT PARA CLASIFICACIÓN ===
# 1. Email: Reunión de equipo mañana a las 10 AM en sala de co...
#    Clasificación: TRABAJO
# 2. Email: ¡Felicidades! Has ganado $1,000,000! Haz clic aquí...
#    Clasificación: SPAM
# 3. Email: Recordatorio: Tu factura de internet vence en 3 dí...
#    Clasificación: PERSONAL

# %%
# 2. GENERACIÓN DE CONTENIDO
def zero_shot_generacion():
    print("=== ZERO-SHOT PARA GENERACIÓN ===")

    # Prompt estructurado para generación
    generacion_prompt = """Eres un copywriter creativo especializado en redes sociales.

Tarea: Crear un post para LinkedIn sobre el tema dado.

Requisitos:
- Tono profesional pero accesible
- Máximo 150 palabras
- Incluir 1-2 hashtags relevantes
- Hacer una pregunta para fomentar engagement

Tema: "Importancia del aprendizaje continuo en tecnología"

Post para LinkedIn:"""

    try:
        response = llm.invoke([HumanMessage(content=generacion_prompt)])
        print("Post generado:")
        print("-" * 40)
        print(response.content)
        print("-" * 40)

        # Análisis del resultado
        words = len(response.content.split())
        hashtags = response.content.count('#')
        questions = response.content.count('?')

        print(f"\nAnálisis:")
        print(f"• Palabras: {words} (límite: 150)")
        print(f"• Hashtags: {hashtags}")
        print(f"• Preguntas: {questions}")
        print(f"• Cumple requisitos: {'✓' if words <= 150 and hashtags >= 1 and questions >= 1 else '✗'}")

    except Exception as e:
        print(f"Error: {e}")

# Ejecutar generación
zero_shot_generacion()
# Out:
# === ZERO-SHOT PARA GENERACIÓN ===
# Post generado:
# ----------------------------------------
# **🚀 ¿Estás listo para el futuro?**
#
# En un mundo donde la tecnología avanza a velocidad de luz, **el aprendizaje continuo ya no es una opción, es una necesidad**. Quienes dominan las últimas herramientas, tendencias y metodologías no solo se mantienen relevantes, sino que **marcan la diferencia en sus equipos y proyectos**.
#
# La innovación no espera. Cada día surgen nuevas soluciones, lenguajes de programación, frameworks y formas de trabajar. **¿Cómo te aseguras de no quedarte atrás?**
#
# 🔹 Invierte en microcursos o certificaciones.
# 🔹 Dedica tiempo a explorar nuevas tecnologías.
# 🔹 Conecta con comunidades que compartan tu pasión.
#
# El que aprende, lidera. **¿Cuál es tu próximo paso en tu camino de crecimiento tecnológico?**
#
# #AprendizajeContinuo #TecnologíaEnEvolución
# ----------------------------------------
#
# Análisis:
# • Palabras: 113 (límite: 150)
# • Hashtags: 2
# • Preguntas: 3
# • Cumple requisitos: ✓

# %%
# 3. EXTRACCIÓN DE INFORMACIÓN
def zero_shot_extraccion():
    print("=== ZERO-SHOT PARA EXTRACCIÓN ===")

    # Texto de ejemplo
    texto_noticia = """Apple Inc. anunció hoy que su CEO Tim Cook se reunirá con inversores
    el próximo 15 de marzo de 2024 en Cupertino, California. La reunión abordará los
    resultados financieros del Q1 2024, donde la compañía reportó ingresos de $89.5
    billones. Cook también discutirá la nueva estrategia de IA de Apple y el lanzamiento
    del iPhone 16 programado para septiembre. Las acciones de Apple (AAPL) subieron
    3.2% tras el anuncio."""

    # Prompt para extracción estructurada
    extraccion_prompt = f"""Eres un analista financiero experto en extraer datos clave.

Extrae la siguiente información del texto dado:

Formato de respuesta (JSON):
{{
  "empresa": "nombre de la empresa",
  "ceo": "nombre del CEO",
  "fecha_evento": "fecha del evento",
  "ubicacion": "ubicación del evento",
  "ingresos": "cifra de ingresos mencionada",
  "productos": ["lista de productos mencionados"],
  "cambio_acciones": "porcentaje de cambio en acciones"
}}

Texto: "{texto_noticia}"

JSON:"""

    try:
        response = llm.invoke([HumanMessage(content=extraccion_prompt)])
        print("Información extraída:")
        print(response.content)

        # Intentar parsear como JSON para validar formato
        import json
        try:
            data = json.loads(response.content)
            print("\n✓ Formato JSON válido")
            print(f"✓ Campos extraídos: {len(data)} elementos")
        except:
            print("\n✗ Formato JSON inválido - necesita refinamiento del prompt")

    except Exception as e:
        print(f"Error: {e}")

# Ejecutar extracción
zero_shot_extraccion()
# Out:
# === ZERO-SHOT PARA EXTRACCIÓN ===
# Información extraída:
# ```json
# {
#   "empresa": "Apple Inc.",
#   "ceo": "Tim Cook",
#   "fecha_evento": "15 de marzo de 2024",
#   "ubicacion": "Cupertino, California",
#   "ingresos": "$89.5 billones",
#   "productos": ["iPhone 16"],
#   "cambio_acciones": "3.2%"
# }
# ```
#
# ✗ Formato JSON inválido - necesita refinamiento del prompt

# %% [markdown]
# ## Optimización de Prompts Zero-Shot
#
# Técnicas para mejorar la efectividad de prompts zero-shot.

# %%
# Técnica 1: Prompts con Roles Específicos
def roles_especificos():
    print("=== OPTIMIZACIÓN: ROLES ESPECÍFICOS ===")

    pregunta = "¿Cómo puedo mejorar el rendimiento de mi aplicación web?"

    roles = {
        "Genérico": "Responde la siguiente pregunta:",
        "Desarrollador Senior": "Eres un desarrollador senior con 10 años de experiencia en optimización web. Responde como un experto:",
        "Consultor de Performance": "Eres un consultor especializado en performance web que ha optimizado cientos de aplicaciones. Proporciona una respuesta detallada y técnica:",
        "CTO": "Eres un CTO de una startup tecnológica. Responde con una perspectiva estratégica y técnica balanceada:"
    }

    for rol, contexto in roles.items():
        prompt = f"{contexto}\n\n{pregunta}"

        print(f"\n{rol.upper()}:")
        print("-" * 30)

        try:
            response = llm.invoke([HumanMessage(content=prompt)])
            # Mostrar solo las primeras líneas para comparación
            preview = response.content[:200] + "..." if len(response.content) > 200 else response.content
            print(preview)
        except Exception as e:
            print(f"Error: {e}")

    print("\n=== OBSERVACIONES ===")
    print("• Roles específicos generan respuestas más enfocadas")
    print("• La experticia del rol influye en la profundidad técnica")
    print("• El contexto profesional afecta el tipo de soluciones propuestas")

# Ejecutar ejemplo de roles
roles_especificos()
# Out:
# === OPTIMIZACIÓN: ROLES ESPECÍFICOS ===
#
# GENÉRICO:
# ------------------------------
# Mejorar el rendimiento de una aplicación web implica optimizar tanto el **frontend** (lo que el usuario ve) como el **backend** (la lógica y servidores) y la **infraestructura** (red, bases de datos, ...
#
# DESARROLLADOR SENIOR:
# ------------------------------
# ¡Claro! Como desarrollador senior con más de una década optimizando aplicaciones web, puedo darte un enfoque **técnico y práctico** basado en métricas reales (LCP, FID, CLS, TTI) y buenas prácticas co...
#
# CONSULTOR DE PERFORMANCE:
# ------------------------------
# Mejorar el rendimiento de una aplicación web requiere un enfoque **multidimensional** que abarque desde el código frontend hasta la infraestructura backend, pasando por optimizaciones de red, caché y ...
#
# CTO:
# ------------------------------
# Como CTO de una startup tecnológica, abordaría la optimización del rendimiento de tu aplicación web desde una perspectiva **estratégica** (alineada con objetivos de negocio) y **técnica** (con métrica...
#
# === OBSERVACIONES ===
# • Roles específicos generan respuestas más enfocadas
# • La experticia del rol influye en la profundidad técnica
# • El contexto profesional afecta el tipo de soluciones propuestas

# %%
# Técnica 2: Instrucciones Graduales
def instrucciones_graduales():
    print("=== OPTIMIZACIÓN: INSTRUCCIONES GRADUALES ===")

    # Problema complejo para demostrar
    problema = "Necesito crear una estrategia de marketing digital para lanzar una nueva app de fitness"

    # Prompt con instrucciones graduales
    prompt_gradual = f"""Eres un estratega de marketing digital senior.

Problema: {problema}

Desarrolla una estrategia siguiendo este proceso paso a paso:

PASO 1: Análisis inicial
- Identifica el público objetivo
- Define 3 puntos de valor únicos de la app

PASO 2: Canales de marketing
- Selecciona 4-5 canales digitales más efectivos
- Justifica cada selección

PASO 3: Estrategia de contenido
- Define tipos de contenido para cada canal
- Sugiere frecuencia de publicación

PASO 4: Métricas y KPIs
- Define 5 métricas clave para medir éxito
- Sugiere herramientas de medición

Desarrolla cada paso con detalle:"""

    try:
        response = llm.invoke([HumanMessage(content=prompt_gradual)])
        print("ESTRATEGIA DESARROLLADA:")
        print("=" * 50)
        print(response.content)

        # Análisis de estructura
        pasos_detectados = response.content.count("PASO")
        secciones = ["análisis", "canales", "contenido", "métricas"]
        secciones_encontradas = sum(1 for seccion in secciones if seccion.lower() in response.content.lower())

        print("\n=== ANÁLISIS DE ESTRUCTURA ===")
        print(f"• Pasos identificados: {pasos_detectados}/4")
        print(f"• Secciones cubiertas: {secciones_encontradas}/4")
        print(f"• Estructura seguida: {'✓' if pasos_detectados >= 3 else '✗'}")

    except Exception as e:
        print(f"Error: {e}")

# Ejecutar instrucciones graduales
instrucciones_graduales()
# Out:
# === OPTIMIZACIÓN: INSTRUCCIONES GRADUALES ===
# ESTRATEGIA DESARROLLADA:
# ==================================================
# ### **Estrategia de Marketing Digital para el Lanzamiento de una App de Fitness**
# **Objetivo:** Posicionar la app como una solución innovadora y accesible para usuarios que buscan mejorar su rendimiento físico, con un enfoque en retención y engagement.
#
# ---
#
# ## **🔹 PASO 1: ANÁLISIS INICIAL**
#
# ### **🎯Público Objetivo (Buyer Persona)**
# **Segmentación demográfica:**
# - **Edad:** 18–45 años (con subgrupos clave: 18–25, 26–35, 36–45).
# - **Género:** Mixto, con mayor enfoque en mujeres (60%) y hombres (40%), ya que las mujeres son más activas en fitness digital (según estudios de *Statista*).
# - **Ubicación:** Países hispanohablantes (España, México, Colombia, Argentina, Perú) + EE.UU. (mercado en crecimiento en fitness digital).
# - **Nivel socioeconómico:** Clase media-media alta (ingresos $1,500–$4,000/mes).
# - **Intereses:**
#   - Salud y bienestar.
#   - Tecnología fitness (wearables, apps).
#   - Nutrición y entrenamiento personalizado.
#   - Comunidades fitness (Instagram, TikTok, Reddit).
#
# **Comportamiento:**
# - Usa apps de fitness (MyFitnessPal, Nike Training Club, Freeletics).
# - Consume contenido de influencers fitness (YouTube, Instagram, TikTok).
# - Valora la personalización y la gamificación (retos, recompensas).
# - Prefiere soluciones "todo en uno" (entrenamiento + nutrición + seguimiento).
#
# **Dolores (Pain Points):**
# - Falta de tiempo para ir al gimnasio.
# - Apps genéricas que no se adaptan a sus necesidades.
# - Desmotivación por falta de seguimiento o comunidad.
# - Desconfianza en la efectividad de los planes gratuitos.
#
# ---
#
# ### **💎3 Puntos de Valor Únicos (USP)**
# 1. **Personalización extrema con IA**
#    - La app usa *machine learning* para adaptar rutinas, nutrición y seguimiento en tiempo real según objetivos, nivel de fitness y preferencias.
#    - Ejemplo: Si el usuario marca "quemar grasa", la IA genera un plan con ejercicios HIIT + recetas de dieta cetogénica.
#
# 2. **Gamificación y comunidad social**
#    - Sistema de retos semanales con recompensas (desbloqueo de planes premium, badges, descuentos en marcas colaboradoras).
#    - Función de "duelos" con amigos o usuarios aleatorios (similar a *Strava* pero con enfoque en fitness).
#    - Integración con Apple Health, Google Fit y wearables (Fitbit, Garmin).
#
# 3. **Enfoque en resultados medibles y sostenibles**
#    - Dashboard con métricas de progreso (fuerza, resistencia, pérdida de grasa) + informes mensuales.
#    - Asesoramiento nutricional con nutricionistas certificados (opción de consulta virtual).
#    - Contenido educativo (videos, podcasts) sobre hábitos saludables (no solo ejercicios).
#
# ---
#
# ## **🔹 PASO 2: CANALES DE MARKETING (SELECCIÓN + JUSTIFICACIÓN)**
#
# | **Canal**          | **Justificación** | **Objetivo Principal** |
# |--------------------|------------------|------------------------|
# | **📱 Redes Sociales (Instagram + TikTok)** | El 70% de los usuarios de fitness consumen contenido en estas plataformas (*HubSpot*). TikTok tiene un algoritmo que premia el contenido viral de fitness. | Generar *brand awareness*, engagement y descargas. |
# | **🎙️ YouTube (Contenido largo + Shorts)** | Ideal para tutoriales de ejercicios, reseñas de productos y testimonios de usuarios. Los *Shorts* pueden redirigir tráfico a la app. | Educar, demostrar valor y convertir leads. |
# | **📧 Email Marketing (Automatizado)** | Canal de alto ROI ($36 por $1 invertido, según *DMA*). Útil para nutrir leads y retener usuarios con contenido personalizado. | Conversión post-descarga y fidelización. |
# | **🤝 Influencers y Microinfluencers** | Los influencers fitness (especialmente micro) tienen alta engagement y credibilidad en nichos específicos (ej: yoga, calistenia, powerlifting). | Generar confianza y llegar a audiencias hipersegmentadas. |
# | **🔍 SEO + Google Ads (Búsqueda)** | Los usuarios buscan soluciones como "app para perder peso" o "rutina de gym en casa". El SEO orgánico atrae tráfico cualificado. | Capturar intenciones de búsqueda y generar leads. |
#
# **📌 Canales secundarios (opcionales):**
# - **Reddit** (subreddits como r/Fitness, r/loseit) para discusiones orgánicas y AMA (*Ask Me Anything*) con expertos.
# - **Podcasts** (patrocinios en programas de salud/wellness).
# - **WhatsApp/Telegram** (comunidades de usuarios premium).
#
# ---
#
# ## **🔹 PASO 3: ESTRATEGIA DE CONTENIDO**
#
# ### **📌 Tipos de Contenido por Canal**
#
# | **Canal**          | **Tipo de Contenido** | **Frecuencia** | **Ejemplo** |
# |--------------------|----------------------|----------------|-------------|
# | **Instagram** | - Reels (ejercicios en 15–30 seg). <br> - Carruseles (rutinas de 7 días). <br> - Stories (encuestas, Q&A, testimonios). <br> - IG Lives (sesiones con entrenadores). | 3–4 Reels/semana <br> 2 Stories/día <br> 1 Live/semana | *"3 ejercicios para glúteos en casa"* (Reel) + enlace en bio. |
# | **TikTok** | - Contenido viral (desafíos, antes/después). <br> - Duetos con influencers. <br> - Tutoriales rápidos (ej: "Cómo hacer sentadillas perfectas"). | 4–5 videos/semana | *"Retos de 30 días para abdomen plano"* (con hashtag #AppFitnessChallenge). |
# | **YouTube** | - Videos largos (rutinas de 20–40 min). <br> - Reviews de productos (wearables, suplementos). <br> - Vlogs de transformación de usuarios. <br> - Shorts (fragmentos de videos largos). | 1 video largo/semana <br> 3 Shorts/semana | *"Plan de 6 semanas para ganar músculo (con dieta inclusa)"*. |
# | **Email Marketing** | - Newsletters semanales (consejos, descuentos). <br> - Secuencias de onboarding para nuevos usuarios. <br> - Retargeting (abandonos de carrito). <br> - Contenido exclusivo para premium. | 1 email/semana <br> 3 emails de onboarding (días 1, 3, 7) | *"Tu progreso esta semana: +2% de fuerza en piernas 💪"*. |
# | **Influencers** | - Reseñas honestas de la app. <br> - Lives demostrando funcionalidades. <br> - Códigos de descuento exclusivos. | 1–2 colaboraciones/mes | Influencer de calistenia probando la app y comparándola con otras. |
#
# ### **📅 Calendario de Contenido (Primer Mes)**
# | **Semana** | **Instagram** | **TikTok** | **YouTube** | **Email** | **Influencers** |
# |------------|--------------|------------|-------------|-----------|-----------------|
# | **Semana 1** | Lanzamiento (Reel + Story) | Video viral (#AppFitnessChallenge) | Trailer de la app (1 min) | Bienvenida + guía rápida | 1 microinfluencer (nano) |
# | **Semana 2** | Carrusel (7 ejercicios para principiantes) | Tutorial rápido (ejercicio del día) | Video: "Cómo usar la IA para personalizar tu rutina" | Newsletter: "Errores comunes en fitness" | 1 influencer medio (100K–500K seguidores) |
# | **Semana 3** | IG Live con entrenador | Dueto con influencer (retos) | Review de productos compatibles | Oferta por tiempo limitado | 1 colaborador (marca de suplementos) |
# | **Semana 4** | Historias con testimonios | Before/After de usuario | Vlog de transformación (case study) | Encuesta de satisfacción | Live con nutricionista |
#
# ---
#
# ## **🔹 PASO 4: MÉTRICAS Y KPIs**
#
# ### **📊 5 Métricas Clave para Medir Éxito**
# | **Métrica** | **Definición** | **Meta (Primeros 3 Meses)** | **Herramienta** |
# |-------------|---------------|-----------------------------|-----------------|
# | **1. Tasa de Descargas (Conversión)** | % de usuarios que descargan la app después de ver un anuncio o landing page. | 5–8% (vs. media industria: 3–5%) | Google Analytics, Firebase |
# | **2. Costo por Adquisición (CPA)** | Inversión en marketing / Número de usuarios adquiridos. | <$5 USD por usuario | Google Ads, Meta Ads Manager |
# | **3. Tasa de Retención (Day 1, 7, 30)** | % de usuarios que usan la app al menos una vez en X días. | Day 1: 40% <br> Day 7: 20% <br> Day 30: 10% | Firebase, Amplitude |
# | **4. Engagement (Uso Activo)** | Promedio de sesiones por usuario/semana. | 3+ sesiones/semana | Mixpanel, App Annie |
# | **5. Net Promoter Score (NPS)** | Métrica de satisfacción (0–10). Usuarios que recomendarían la app. | NPS ≥ 50 | Encuestas en-app (Typeform) |
#
# ### **🛠️ Herramientas de Medición**
# | **Herramienta** | **Uso** |
# |-----------------|---------|
# | **Google Analytics 4 (GA4)** | Seguimiento de tráfico web y conversiones. |
# | **Firebase** | Analítica de la app (retención, eventos en-app). |
# | **Meta Ads Manager** | Métricas de campañas en Facebook/Instagram. |
# | **TikTok Ads Manager** | Rendimiento de anuncios en TikTok. |
# | **Hotjar** | Grabaciones de usuarios y heatmaps en landing page. |
# | **Amplitude/Mixpanel** | Análisis avanzado de comportamiento en-app. |
# | **Mailchimp/Klaviyo** | Métricas de email marketing (open rate, CTR). |
# | **Typeform/Google Forms** | Encuestas de satisfacción (NPS, feedback). |
#
# ---
# ### **🚀 Conclusión: Roadmap de Lanzamiento**
# 1. **Pre-lanzamiento (2 semanas antes):**
#    - Crear *teaser* en redes con countdown.
#    - Landing page con lista de espera (captura emails).
#    - Campaña de influencers (envío anticipado de la app).
#
# 2. **Día 1 (Lanzamiento):**
#    - Push notification a usuarios en lista de espera.
#    - Anuncios en Meta/TikTok con código de descuento.
#    - Live en Instagram con el CEO explicando la app.
#
# 3. **Primeros 3 meses:**
#    - Optimizar campañas con datos de retención.
#    - Lanzar programa de referidos ("Trae a un amigo y gana 1 mes premium").
#    - Expandir a mercados secundarios (ej: Brasil, si hay demanda).
#
# **💡 Bonus:**
# - **A/B Testing:** Probar diferentes mensajes en anuncios (ej: "Pierde 5 kg en 30 días" vs. "Entrena como un profesional").
# - **Gamificación:** Recompensar a los usuarios más activos con badges o descuentos en marcas aliadas.
#
# ---
# **¿Necesitas ajustar algún elemento?** Por ejemplo, si el presupuesto es limitado, podríamos priorizar TikTok e Instagram sobre YouTube, o enfocarnos en microinfluencers para reducir costos. ¡Déjame saber! 🚀
#
# === ANÁLISIS DE ESTRUCTURA ===
# • Pasos identificados: 4/4
# • Secciones cubiertas: 4/4
# • Estructura seguida: ✓

# %% [markdown]
# ## Casos de Uso Avanzados
#
# Aplicaciones más sofisticadas de zero-shot prompting.

# %%
# Caso de uso: Análisis de código
def analisis_codigo_zero_shot():
    print("=== CASO DE USO: ANÁLISIS DE CÓDIGO ===")

    codigo_ejemplo = '''def process_user_data(users):
    result = []
    for user in users:
        if user["age"] > 18:
            result.append({
                "name": user["name"].upper(),
                "email": user["email"],
                "status": "adult"
            })
    return result'''

    prompt_analisis = f"""Eres un senior code reviewer con experiencia en Python.

Analiza el siguiente código y proporciona:

1. FUNCIONALIDAD:
   - ¿Qué hace este código?
   - ¿Cuál es su propósito?

2. PROBLEMAS POTENCIALES:
   - Errores de lógica
   - Vulnerabilidades de seguridad
   - Problemas de rendimiento

3. MEJORAS SUGERIDAS:
   - Optimizaciones de código
   - Mejores prácticas
   - Manejo de errores

4. PUNTUACIÓN DE CALIDAD: [1-10]

Código a analizar:
```python
{codigo_ejemplo}
```

Análisis:"""

    try:
        response = llm.invoke([HumanMessage(content=prompt_analisis)])
        print("ANÁLISIS DE CÓDIGO:")
        print("=" * 50)
        print(response.content)

    except Exception as e:
        print(f"Error: {e}")

# Ejecutar análisis de código
analisis_codigo_zero_shot()
# Out:
# === CASO DE USO: ANÁLISIS DE CÓDIGO ===
# ANÁLISIS DE CÓDIGO:
# ==================================================
# ### **1. FUNCIONALIDAD**
# **¿Qué hace este código?**
# - El código procesa una lista de diccionarios (`users`) que representan usuarios.
# - Para cada usuario, verifica si su edad (`age`) es mayor a 18.
# - Si cumple la condición, añade un nuevo diccionario a `result` con:
#   - `name` en mayúsculas.
#   - `email` sin modificar.
#   - `status` como `"adult"`.
#
# **Propósito:**
# - Filtrar usuarios mayores de edad y transformar sus datos para un formato específico (ej.: generar un informe, enviar notificaciones, etc.).
#
# ---
#
# ### **2. PROBLEMAS POTENCIALES**
#
# #### **Errores de lógica**
# 1. **Falta validación de claves en el diccionario `user`:**
#    - Si un usuario no tiene la clave `"age"`, `"name"` o `"email"`, el código lanzará `KeyError`.
#    - Ejemplo: `user = {"name": "Alice", "email": "alice@example.com"}` (falta `"age"`).
#
# 2. **Tipos de datos no verificados:**
#    - Si `"age"` no es un entero (ej.: `None`, `"30"`, `float`), la comparación `user["age"] > 18` puede fallar o dar resultados inesperados.
#    - Si `"name"` o `"email"` no son cadenas, `.upper()` o el acceso directo podrían fallar.
#
# 3. **Lógica incompleta para menores de edad:**
#    - No hay manejo para usuarios menores de 18 años. ¿Deberían incluirse en `result` con otro `status`?
#
# #### **Vulnerabilidades de seguridad**
# 1. **Inyección de datos:**
#    - Si `users` proviene de una fuente no confiable (ej.: API externa), un atacante podría manipular los datos para causar errores o comportamiento inesperado.
#    - Ejemplo: Si `"name"` contiene scripts HTML, podría usarse en un contexto donde se renderice sin escapar.
#
# 2. **Falta de sanitización de `email`:**
#    - El correo electrónico se copia tal cual sin validar su formato (ej.: `"user@example..com"`).
#
# #### **Problemas de rendimiento**
# 1. **Uso innecesario de memoria:**
#    - `result` se construye con una lista que podría ser muy grande si `users` tiene muchos usuarios mayores de 18.
#
# 2. **Ineficiencia en bucles:**
#    - Para listas muy grandes, un `for` tradicional es aceptable, pero en contextos de alto rendimiento (ej.: big data), podría optimizarse con comprensiones de listas o `map()`.
#
# ---
#
# ### **3. MEJORAS SUGERIDAS**
#
# #### **Optimizaciones y mejores prácticas**
# 1. **Validación de datos:**
#    ```python
#    def process_user_data(users):
#        result = []
#        for user in users:
#            try:
#                if not isinstance(user.get("age"), int):
#                    continue  # O manejar el error según el caso
#                if user["age"] <= 18:
#                    continue
#                name = user["name"].upper() if isinstance(user["name"], str) else ""
#                email = user["email"] if isinstance(user["email"], str) else ""
#                result.append({
#                    "name": name,
#                    "email": email,
#                    "status": "adult"
#                })
#            except KeyError:
#                # Loguear o manejar el error
#                continue
#        return result
#    ```
#
# 2. **Uso de comprensiones de listas (más Pythonico):**
#    ```python
#    def process_user_data(users):
#        return [
#            {
#                "name": user["name"].upper(),
#                "email": user["email"],
#                "status": "adult"
#            }
#            for user in users
#            if user.get("age", 0) > 18
#            and isinstance(user.get("name"), str)
#            and isinstance(user.get("email"), str)
#        ]
#    ```
#
# 3. **Sanitización básica de `email`:**
#    ```python
#    import re
#    def is_valid_email(email):
#        return re.match(r"[^@]+@[^@]+\.[^@]+", email) is not None
#
#    # Luego en el código:
#    if not is_valid_email(user["email"]):
#        continue  # O manejar el error
#    ```
#
# 4. **Manejo de errores explícito:**
#    - Usar `try-except` o validaciones con `if`/`else` para evitar fallos silenciosos.
#    - Considerar devolver un diccionario con `{"success": bool, "data": list, "errors": list}` para mayor claridad.
#
# 5. **Documentación y tipos:**
#    - Añadir docstring y anotaciones de tipos:
#      ```python
#      from typing import List, Dict, Any
#
#      def process_user_data(users: List[Dict[str, Any]]) -> List[Dict[str, str]]:
#          """Procesa usuarios mayores de 18 años y devuelve sus datos formateados.
#
#          Args:
#              users: Lista de diccionarios con claves 'age', 'name' y 'email'.
#
#          Returns:
#              Lista de diccionarios con claves 'name', 'email' y 'status'.
#          """
#          ...
#      ```
#
# 6. **Manejo de casos límite:**
#    - ¿Qué pasa si `age` es `None`? ¿O si `name`/`email` están vacíos?
#    - Ejemplo de manejo:
#      ```python
#      age = user.get("age")
#      if age is None or not isinstance(age, int):
#          # Saltar o asignar un valor por defecto
#          continue
#      ```
#
# #### **Alternativas avanzadas**
# - **Uso de `dataclasses` o `pydantic` para validación estricta:**
#   ```python
#   from pydantic import BaseModel, validator
#
#   class User(BaseModel):
#       age: int
#       name: str
#       email: str
#
#       @validator("age")
#       def age_must_be_positive(cls, v):
#           if v <= 0:
#               raise ValueError("Age must be positive")
#           return v
#
#   def process_user_data(users: list[User]) -> list[dict]:
#       return [
#           {"name": user.name.upper(), "email": user.email, "status": "adult"}
#           for user in users
#           if user.age > 18
#       ]
#   ```
#
# ---
#
# ### **4. PUNTUACIÓN DE CALIDAD: 6/10**
# **Razones:**
# ✅ **Ventajas:**
# - Código simple y fácil de entender.
# - Cumple su propósito básico.
#
# ❌ **Deficiencias:**
# - **Falta validación de datos** (riesgo de errores en tiempo de ejecución).
# - **No maneja casos de borde** (ej.: `age` como `None`, tipos incorrectos).
# - **Vulnerabilidades potenciales** (inyección de datos, sanitización insuficiente).
# - **Poco robusto** para producción (ej.: sin manejo de errores detallado).
# - **Sin documentación ni anotaciones de tipos**.
#
# **Mejoras clave para llegar a 9/10:**
# 1. Validar todas las claves del diccionario `user`.
# 2. Añadir manejo de errores y logging.
# 3. Sanitizar `email` y otros campos sensibles.
# 4. Documentar el código y usar anotaciones de tipos.
# 5. Considerar `pydantic` o `dataclasses` para validación estricta.
#
# ---
# **Conclusión:**
# El código es funcional para un caso de uso muy básico, pero requiere mejoras significativas para ser robusto, seguro y mantenible en un entorno de producción.

# %%
# Caso de uso: Generación de tests
def generacion_tests_zero_shot():
    print("=== CASO DE USO: GENERACIÓN DE TESTS ===")

    funcion_a_testear = '''def calculate_discount(price, discount_percent, user_type):
    """Calculate final price after discount.

    Args:
        price (float): Original price
        discount_percent (float): Discount percentage (0-100)
        user_type (str): 'premium' or 'regular'

    Returns:
        float: Final price after discount
    """
    if user_type == 'premium':
        discount_percent += 5  # Extra 5% for premium users

    discount_amount = price * (discount_percent / 100)
    return price - discount_amount'''

    prompt_tests = f"""Eres un QA engineer experto en testing de Python.

Genera tests unitarios completos para la siguiente función usando pytest.

Incluye tests para:
1. Casos normales (diferentes tipos de usuario y descuentos)
2. Casos edge (descuento 0%, 100%, valores negativos)
3. Casos de error (tipos incorrectos, valores inválidos)
4. Tests parametrizados cuando sea apropiado

Función a testear:
```python
{funcion_a_testear}
```

Genera código de test completo y ejecutable:"""

    try:
        response = llm.invoke([HumanMessage(content=prompt_tests)])
        print("TESTS GENERADOS:")
        print("=" * 50)
        print(response.content)

        # Análisis básico de los tests generados
        test_methods = response.content.count("def test_")
        assertions = response.content.count("assert")
        parametrize = response.content.count("@pytest.mark.parametrize")

        print("\n=== ANÁLISIS DE TESTS ===")
        print(f"• Métodos de test: {test_methods}")
        print(f"• Assertions: {assertions}")
        print(f"• Tests parametrizados: {parametrize}")
        print(f"• Cobertura estimada: {'Alta' if test_methods >= 5 else 'Media' if test_methods >= 3 else 'Baja'}")

    except Exception as e:
        print(f"Error: {e}")

# Ejecutar generación de tests
generacion_tests_zero_shot()
# Out:
# === CASO DE USO: GENERACIÓN DE TESTS ===
# TESTS GENERADOS:
# ==================================================
# # Tests Unitarios para `calculate_discount` con pytest
#
# Aquí tienes un conjunto completo de tests unitarios para la función `calculate_discount` usando pytest, cubriendo todos los casos solicitados:
#
# ```python
# import pytest
# from unittest.mock import patch
# from your_module import calculate_discount  # Reemplaza 'your_module' con el nombre real del módulo
#
# class TestCalculateDiscount:
#     """Test suite for calculate_discount function."""
#
#     # ========== Casos normales ==========
#     @pytest.mark.parametrize("price, discount_percent, user_type, expected", [
#         (100.0, 10.0, 'regular', 90.0),  # Descuento estándar para usuario regular
#         (200.0, 15.0, 'premium', 165.0),  # Descuento con extra para premium
#         (50.0, 0.0, 'regular', 50.0),  # Sin descuento
#         (100.0, 100.0, 'regular', 0.0),  # Descuento del 100%
#         (75.5, 20.0, 'premium', 57.125),  # Precio con decimales
#         (1000.0, 50.0, 'regular', 500.0),  # Descuento grande
#     ])
#     def test_normal_cases(self, price, discount_percent, user_type, expected):
#         """Test normal cases with different prices, discounts and user types."""
#         result = calculate_discount(price, discount_percent, user_type)
#         assert result == expected
#
#     # ========== Casos edge ==========
#     @pytest.mark.parametrize("price, discount_percent, user_type", [
#         (0.0, 10.0, 'regular'),  # Precio cero
#         (100.0, 0.0, 'premium'),  # Descuento 0% para premium (debería dar 5% extra)
#         (100.0, 100.0, 'premium'),  # Descuento 100% para premium (debería dar 105%)
#         (-100.0, 10.0, 'regular'),  # Precio negativo (debería fallar)
#         (100.0, -5.0, 'regular'),  # Descuento negativo (debería fallar)
#         (100.0, 105.0, 'regular'),  # Descuento >100%
#     ])
#     def test_edge_cases(self, price, discount_percent, user_type):
#         """Test edge cases including zero price, extreme percentages."""
#         if price < 0 or discount_percent < 0 or discount_percent > 100:
#             with pytest.raises(ValueError):
#                 calculate_discount(price, discount_percent, user_type)
#         else:
#             # Para estos casos, calculamos el resultado esperado manualmente
#             if user_type == 'premium' and discount_percent <= 100:
#                 expected_discount = discount_percent + 5
#             else:
#                 expected_discount = discount_percent
#
#             expected_discount = min(expected_discount, 100)  # No superar 100%
#             discount_amount = price * (expected_discount / 100)
#             expected = price - discount_amount
#
#             result = calculate_discount(price, discount_percent, user_type)
#             assert result == expected
#
#     # ========== Casos de error ==========
#     @pytest.mark.parametrize("price, discount_percent, user_type, error_type", [
#         (None, 10.0, 'regular', TypeError),  # Precio None
#         (100.0, None, 'regular', TypeError),  # Descuento None
#         (100.0, 10.0, None, TypeError),  # User type None
#         ('100.0', 10.0, 'regular', TypeError),  # Precio como string
#         (100.0, '10.0', 'regular', TypeError),  # Descuento como string
#         (100.0, 10.0, 'gold', ValueError),  # Tipo de usuario inválido
#         (100.0, 10.0, 123, TypeError),  # User type como número
#     ])
#     def test_error_cases(self, price, discount_percent, user_type, error_type):
#         """Test error cases with invalid input types and values."""
#         with pytest.raises(error_type):
#             calculate_discount(price, discount_percent, user_type)
#
#     # ========== Tests adicionales ==========
#     def test_precision_float(self):
#         """Test floating point precision in calculations."""
#         result = calculate_discount(100.0, 10.0, 'regular')
#         assert result == pytest.approx(90.0, rel=1e-9)
#
#         result = calculate_discount(100.0, 10.0, 'premium')
#         assert result == pytest.approx(85.0, rel=1e-9)
#
#     @pytest.mark.parametrize("user_type", ['Premium', 'REGULAR', 'Premium Premium'])
#     def test_user_type_case_sensitivity(self, user_type):
#         """Test that user_type is case sensitive."""
#         if user_type.lower() not in ['premium', 'regular']:
#             with pytest.raises(ValueError):
#                 calculate_discount(100.0, 10.0, user_type)
#         else:
#             # Si es válido (excepto por la capitalización), debería funcionar
#             result = calculate_discount(100.0, 10.0, user_type)
#             assert result == 90.0
#
#     def test_large_numbers(self):
#         """Test with very large numbers to check for overflow or performance issues."""
#         large_price = 1e10
#         result = calculate_discount(large_price, 10.0, 'regular')
#         assert result == large_price * 0.9
#
#         result = calculate_discount(large_price, 10.0, 'premium')
#         assert result == large_price * 0.85
# ```
#
# ## Notas importantes:
#
# 1. **Reemplazo del módulo**: Asegúrate de cambiar `'your_module'` por el nombre real del módulo donde se encuentra la función `calculate_discount`.
#
# 2. **Cobertura de tests**:
#    - **Casos normales**: Diferentes combinaciones de precios, descuentos y tipos de usuario.
#    - **Casos edge**: Valores límite como 0%, 100%, precios negativos, descuentos negativos.
#    - **Casos de error**: Tipos incorrectos y valores inválidos.
#    - **Tests adicionales**: Precisión de punto flotante, sensibilidad a mayúsculas/minúsculas en user_type, y números grandes.
#
# 3. **Validación de errores**: La función no valida actualmente que discount_percent esté entre 0 y 100, ni que user_type sea 'premium' o 'regular'. Los tests asumen que esto debería lanzarse como error (ValueError), pero si la función no valida estos casos, deberías modificar los tests para que pasen sin lanzar errores.
#
# 4. **Ejecución**: Para ejecutar los tests, usa el comando `pytest` en la terminal desde la ubicación del archivo.
#
# 5. **Posible mejora**: Si quieres que la función valide los inputs, podrías modificar la función original para lanzar ValueError cuando:
#    - discount_percent < 0 o > 100
#    - user_type no es 'premium' ni 'regular'
#
# En ese caso, los tests para estos casos pasarían sin necesidad de modificar la lógica de los tests.
#
# === ANÁLISIS DE TESTS ===
# • Métodos de test: 6
# • Assertions: 7
# • Tests parametrizados: 4
# • Cobertura estimada: Alta

# %% [markdown]
# ## Mejores Prácticas y Limitaciones
#
# ### ✅ Cuándo Usar Zero-Shot:
# - Tareas comunes y bien definidas
# - Cuando no tienes ejemplos disponibles
# - Para prototipado rápido
# - Tareas que requieren creatividad
#
# ### ❌ Cuándo NO Usar Zero-Shot:
# - Formatos de salida muy específicos
# - Tareas de dominio muy especializado
# - Cuando la consistencia es crítica
# - Tareas complejas que requieren patrones específicos
#
# ### 🎯 Mejores Prácticas:
# 1. **Sé específico**: Detalla exactamente qué quieres
# 2. **Define el formato**: Especifica cómo debe verse la salida
# 3. **Establece restricciones**: Qué debe evitar o considerar
# 4. **Usa roles**: Define quién debe "ser" el modelo
# 5. **Itera y refina**: Mejora basándote en resultados

# %%
# Ejercicio final: Diseña tu propio prompt zero-shot
def ejercicio_personalizado():
    print("=== EJERCICIO PERSONAL ===")
    print("\nDiseña un prompt zero-shot para esta tarea:")
    print("'Crear una descripción de trabajo atractiva para un puesto de desarrollador Python junior'")
    print("\nEstructura sugerida:")
    print("1. Rol/Contexto del modelo")
    print("2. Tarea específica")
    print("3. Requisitos del formato")
    print("4. Restricciones importantes")
    print("\nTu prompt aquí:")

    # Espacio para que el estudiante diseñe su prompt
    prompt_estudiante = """# COLOCA TU PROMPT AQUÍ

# Ejemplo de estructura:
# Eres un [ROL]...
# Tarea: [TAREA ESPECÍFICA]...
# Formato: [ESTRUCTURA DE SALIDA]...
# Restricciones: [LIMITACIONES]...
"""

    print(prompt_estudiante)

    # Prompt de ejemplo bien estructurado
    ejemplo_prompt = """Eres un HR Business Partner senior especializado en tecnología con 8 años de experiencia reclutando desarrolladores.

Tarea: Redacta una descripción de trabajo atractiva y realista para un puesto de Desarrollador Python Junior.

Formato requerido:
- Título del puesto
- Resumen ejecutivo (2-3 líneas)
- Responsabilidades principales (4-5 puntos)
- Requisitos técnicos (separar esenciales de deseables)
- Beneficios y cultura de empresa
- Llamada a la acción

Restricciones:
- Máximo 400 palabras
- Lenguaje inclusivo y accesible
- Enfócate en crecimiento profesional
- Evita jerga técnica excesiva
- Sé honesto sobre el nivel junior

Descripción de trabajo:"""

    print("\n=== EJEMPLO DE PROMPT BIEN ESTRUCTURADO ===")
    print(ejemplo_prompt)

    # Opcional: probar el prompt ejemplo
    print("\n¿Quieres ver el resultado del prompt ejemplo? (y/n)")
    # En un entorno real, aquí habría input del usuario

ejercicio_personalizado()
# Out:
# === EJERCICIO PERSONAL ===
#
# Diseña un prompt zero-shot para esta tarea:
# 'Crear una descripción de trabajo atractiva para un puesto de desarrollador Python junior'
#
# Estructura sugerida:
# 1. Rol/Contexto del modelo
# 2. Tarea específica
# 3. Requisitos del formato
# 4. Restricciones importantes
#
# Tu prompt aquí:
# # COLOCA TU PROMPT AQUÍ
#
# # Ejemplo de estructura:
# # Eres un [ROL]...
# # Tarea: [TAREA ESPECÍFICA]...
# # Formato: [ESTRUCTURA DE SALIDA]...
# # Restricciones: [LIMITACIONES]...
#
#
# === EJEMPLO DE PROMPT BIEN ESTRUCTURADO ===
# Eres un HR Business Partner senior especializado en tecnología con 8 años de experiencia reclutando desarrolladores.
#
# Tarea: Redacta una descripción de trabajo atractiva y realista para un puesto de Desarrollador Python Junior.
#
# Formato requerido:
# - Título del puesto
# - Resumen ejecutivo (2-3 líneas)
# - Responsabilidades principales (4-5 puntos)
# - Requisitos técnicos (separar esenciales de deseables)
# - Beneficios y cultura de empresa
# - Llamada a la acción
#
# Restricciones:
# - Máximo 400 palabras
# - Lenguaje inclusivo y accesible
# - Enfócate en crecimiento profesional
# - Evita jerga técnica excesiva
# - Sé honesto sobre el nivel junior
#
# Descripción de trabajo:
#
# ¿Quieres ver el resultado del prompt ejemplo? (y/n)

# %% [markdown]
# ## Conceptos Clave Aprendidos
#
# 1. **Zero-shot prompting** es efectivo para tareas comunes sin necesidad de ejemplos
# 2. **Estructura clara** del prompt mejora significativamente los resultados
# 3. **Roles específicos** generan respuestas más enfocadas y expertas
# 4. **Instrucciones graduales** ayudan con tareas complejas
# 5. **Formato definido** asegura salidas consistentes y útiles
#
# ## Próximos Pasos
#
# En el siguiente notebook exploraremos **Few-Shot Prompting**, donde aprenderemos a usar ejemplos específicos para guiar el comportamiento del modelo y lograr mayor consistencia en tareas especializadas.
#
# ### Para Practicar:
# 1. Diseña prompts zero-shot para diferentes tipos de tareas
# 2. Experimenta con diferentes roles y contextos
# 3. Compara resultados con y sin estructura específica
# 4. Mide la consistencia en múltiples ejecuciones
